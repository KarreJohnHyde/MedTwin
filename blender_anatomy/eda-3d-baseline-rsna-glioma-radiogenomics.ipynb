# %% [markdown]
# <br>
#
# <img src="https://i.ibb.co/tYfwcwC/header-1.png" width="100%">
#
# <br>
#
# ---
#
# <br>
#
# <center><h2 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;">EXPLORATORY DATA ANALSYSIS AND SOLUTIONING</h2><h4 style="font-family: Verdana; font-size: 18px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;">TOWARDS BRAIN TUMOR RADIOGENOMIC CLASSIFICATION</h4></center>
#
# <br>
#
# <h5 style="text-align: center; font-family: Verdana; font-size: 14px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: black; background-color: #ffffff;">CREATED BY: DARIEN SCHETTLER</h5><br>
#
# ---
#
# <br>
#
# <div class="alert alert-block alert-danger" style="margin: 2em; line-height: 1.7em; font-family: Verdana;">
#     <br><center><b style="font-size: 16px;">🛑🛑🛑 &nbsp; CAUTION:  THIS NOTEBOOK IS A WORK IN PROGRESS  &nbsp; 🛑🛑🛑</b></center><br>
# </div>
#
# <br>
#
#
# ---
# <br>

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;">TABLE OF CONTENTS</h2>
#
# ---
#
# <h2 style="text-indent: 10vw; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: darkred; background-color: #ffffff;"><a href="#imports">0&nbsp;&nbsp;&nbsp;&nbsp;IMPORTS</a></h2>
#
# ---
#
# <h2 style="text-indent: 10vw; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: darkred; background-color: #ffffff;"><a href="#background_information">1&nbsp;&nbsp;&nbsp;&nbsp;BACKGROUND INFORMATION</a></h2>
#
# ---
#
# <h2 style="text-indent: 10vw; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: darkred; background-color: #ffffff;"><a href="#setup">2&nbsp;&nbsp;&nbsp;&nbsp;SETUP</a></h2>
#
# ---
#
# <h2 style="text-indent: 10vw; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: darkred; background-color: #ffffff;"><a href="#helper_functions">3&nbsp;&nbsp;&nbsp;&nbsp;HELPER FUNCTIONS</a></h2>
#
# ---

# %% [markdown]
# <br>
#
# <a id="imports"></a>
#
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; background-color: #ffffff; color: #CD0001;" id="imports">0&nbsp;&nbsp;IMPORTS</h1>

# %%
print("\n... PIP/APT INSTALLS STARTING ...")
# !cp /kaggle/input/gdcm-conda-install/gdcm.tar .
# !tar -xvzf gdcm.tar
# !conda install --offline ./gdcm/gdcm-2.8.9-py37h71b2a6d_0.tar.bz2
# !rm -rf ./gdcm*
# !pip install efficientnet-3D
# !pip install git+https://github.com/qubvel/classification_models.git
# !pip install -U --pre efficientnet

# !conda install -c conda-forge gdcm -y
# !pip install pandarallel
print("... PIP/APT INSTALLS COMPLETE ...\n")


print("\n... IMPORTS STARTING ...\n")
print("\n\tVERSION INFORMATION")
# Machine Learning and Data Science Imports
import tensorflow as tf; print(f"\t\t– TENSORFLOW VERSION: {tf.__version__}");
import tensorflow_addons as tfa; print(f"\t\t– TENSORFLOW ADDONS VERSION: {tfa.__version__}");
import pandas as pd; pd.options.mode.chained_assignment = None; pd.set_option('max_columns', 100);
import numpy as np; print(f"\t\t– NUMPY VERSION: {np.__version__}");
import efficientnet_3D.tfkeras as efn

# Other Competition Related Imports
import pydicom
from pydicom.pixel_data_handlers.util import apply_voi_lut
from pandarallel import pandarallel; pandarallel.initialize();

# Built In Imports
from kaggle_datasets import KaggleDatasets
from collections import Counter
from datetime import datetime
from glob import glob
import warnings
import requests
import imageio
import IPython
import urllib
import zipfile
import pickle
import random
import shutil
import string
import scipy
import math
import time
import gzip
import ast
import sys
import io
import os
import gc
import re

# Visualization Imports
from matplotlib.colors import ListedColormap
from matplotlib import animation, rc; rc('animation', html='jshtml')
import matplotlib.patches as patches

import plotly.graph_objects as go
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm; tqdm.pandas();
import plotly.express as px
import seaborn as sns
from PIL import Image
import matplotlib; print(f"\t\t– MATPLOTLIB VERSION: {matplotlib.__version__}");
import plotly
import PIL
import cv2
print("\n\n... IMPORTS COMPLETE ...\n")
    

print("\n... SEEDING FOR DETERMINISTIC BEHAVIOUR ...")
def seed_it_all(seed=7):
    """ Attempt to be Reproducible """
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

seed_it_all()
print("... SEEDING COMPLETE ...\n\n")

print("\n... SETTING PRESETS STARTING...")
FIG_FONT = dict(family="Helvetica, Arial", size=14, color="#7f7f7f")
label_map_int_2_str = {0: "MGMT_NEGATIVE", 1: "MGMT_POSITIVE"}
label_map_str_2_int = {"MGMT_NEGATIVE":0, "MGMT_POSITIVE":1}
print("... SETTING PRESETS COMPLETE...\n\n")
# Out:
# ... PIP/APT INSTALLS STARTING ...
# gdcm/
# gdcm/conda-4.8.4-py37hc8dfbb8_2.tar.bz2
# gdcm/gdcm-2.8.9-py37h71b2a6d_0.tar.bz2
# gdcm/libjpeg-turbo-2.0.3-h516909a_1.tar.bz2
#
# Downloading and Extracting Packages
# ######################################################################## | 100%
# done
# done
# done
# Collecting efficientnet-3D
#   Downloading efficientnet_3D-1.0.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: keras>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from efficientnet-3D) (2.4.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from efficientnet-3D) (1.19.5)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras>=2.2.0->efficientnet-3D) (2.10.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras>=2.2.0->efficientnet-3D) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.7/site-packages (from keras>=2.2.0->efficientnet-3D) (1.5.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras>=2.2.0->efficientnet-3D) (1.15.0)
# Installing collected packages: efficientnet-3D
# Successfully installed efficientnet-3D-1.0.1
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-fn2_b7ca
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-fn2_b7ca
#   Running command git submodule update --init --recursive -q
# Collecting keras_applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 726 kB/s
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras_applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0) (1.15.0)
# Building wheels for collected packages: image-classifiers
# done
#   Created wheel for image-classifiers: filename=image_classifiers-1.0.0-py3-none-any.whl size=20030 sha256=8a893567f3ddf2767bd0d3e681e03378a955d7e710cc5af75b76ac53b9b98b0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qoo5v9sd/wheels/0b/96/56/27b17c903efc647c51e4f364bfc20aa67f8d3dccad63c4fb4e
# Successfully built image-classifiers
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from efficientnet) (0.18.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /opt/conda/lib/python3.7/site-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.19.5)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.10.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.15.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (1.1.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (3.4.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (7.2.0)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2.9.0)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (1.5.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2021.4.8)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet) (2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx>=2.0->scikit-image->efficientnet) (4.4.2)
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.1
# Collecting pandarallel
#   Downloading pandarallel-1.5.2.tar.gz (16 kB)
# Requirement already satisfied: dill in /opt/conda/lib/python3.7/site-packages (from pandarallel) (0.3.3)
# Building wheels for collected packages: pandarallel
# done
#   Created wheel for pandarallel: filename=pandarallel-1.5.2-py3-none-any.whl size=18384 sha256=11e4b67e44b6a1143f009f9b2eb13735523a3f41eb29ce70014252704c097522
#   Stored in directory: /root/.cache/pip/wheels/b5/6d/51/9ece2eaf007ea3f7fb0ce053c5773b2eb0d308887da3af12c1
# Successfully built pandarallel
# Installing collected packages: pandarallel
# Successfully installed pandarallel-1.5.2
# ... PIP/APT INSTALLS COMPLETE ...
#
#
# ... IMPORTS STARTING ...
#
#
# 	VERSION INFORMATION
# 		– TENSORFLOW VERSION: 2.4.1
# 		– TENSORFLOW ADDONS VERSION: 0.12.1
# 		– NUMPY VERSION: 1.19.5
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# 		– MATPLOTLIB VERSION: 3.4.1
#
#
# ... IMPORTS COMPLETE ...
#
#
# ... SEEDING FOR DETERMINISTIC BEHAVIOUR ...
# ... SEEDING COMPLETE ...
#
#
#
# ... SETTING PRESETS STARTING...
# ... SETTING PRESETS COMPLETE...

# %% [markdown]
# <br>
#
# <a id="background_information"></a>
#
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;" id="background_information">1&nbsp;&nbsp;BACKGROUND INFORMATION</h1>

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">1.1  OVERVIEW</h2>
#
# ---
#
# <b style="text-decoration: underline; font-family: Verdana;">COMPETITION DESCRIPTION</b>
#
# A malignant tumor in the brain is a life-threatening condition. Known as glioblastoma, it's both the most common form of brain cancer in adults and the one with the worst prognosis, with median survival being less than a year. The presence of a specific genetic sequence in the tumor known as MGMT promoter methylation has been shown to be a favorable prognostic factor and a strong predictor of responsiveness to chemotherapy.
#
# Currently, genetic analysis of cancer requires surgery to extract a tissue sample. Then it can take several weeks to determine the genetic characterization of the tumor. Depending upon the results and type of initial therapy chosen, a subsequent surgery may be necessary. If an accurate method to predict the genetics of the cancer through imaging (i.e., radiogenomics) alone could be developed, this would potentially minimize the number of surgeries and refine the type of therapy required.
#
# The Radiological Society of North America (RSNA) has teamed up with the Medical Image Computing and Computer Assisted Intervention Society (the MICCAI Society) to improve diagnosis and treatment planning for patients with glioblastoma. In this competition you will predict the genetic subtype of glioblastoma using MRI (magnetic resonance imaging) scans to train and test your model to detect for the presence of MGMT promoter methylation.
#
# If successful, you'll help brain cancer patients receive less invasive diagnoses and treatments. The introduction of new and customized treatment strategies before surgery has the potential to improve the management, survival, and prospects of patients with brain cancer.
#
# **Secondary Description From UPenn**
# > The participants are called to use the provided mpMRI data to extract imaging/radiomic features that they consider appropriate, and analyze them through machine learning algorithms, in an attempt to predict the MGMT promoter methylation status. The participants do not need to be limited to volumetric parameters, but can also consider intensity, morphologic, histogram-based, and textural features, as well as spatial information, deep learning features, and glioma diffusion properties extracted from glioma growth models.
#
# > Note that participants will be evaluated for the predicted MGMT status of the subjects indicated in the accompanying spreadsheet.
#
# <br>
#
# <div class="alert alert-block alert-info" style="margin: 2em; line-height: 1.7em; font-family: Verdana;">
#     <br><center><b style="font-size: 16px;">🤔🤔🤔 &nbsp; MY INTERPRETATION OF THIS COMPETITION &nbsp; 🤔🤔🤔</b></center><br><br><b style="font-size: 12px; color: black;">In this competition we are tasked with identifying/predicting the <i>genetic subtype <font color="darkred">(genetic subtype = a group of tumors that is enriched for genetic aberrations in a set of subtype predictor genes)</font></i> of <i>glioblastoma <font color="darkred">(glioblastoma = brain tumor)</font></i><br><br>HUH?!?!?<br><br>All this means is that we are taking in dicom images containing 3D representations (slices) of a patients brain which we will process with computer vision algorithms to allow us to perform binary classification. The binary classification is to identify if, within the patients image data, MGMT promoter methylation is present. The diagram below shows a simple, if slightly inaccurate, representation of what is required.</b><br><br><center><img src="https://www.researchgate.net/profile/Qi-Dou-2/publication/313019762/figure/fig2/AS:691329537433601@1541837214995/The-hierarchical-architecture-of-the-3D-CNN-model.png" width=50%></center><br>
# </div>
#
# ---
#
# <br>
#
# <b style="text-decoration: underline; font-family: Verdana;">SUBMISSION EVALUATION/RESTRICTIONS AND FILE FORMAT</b>
#
# **Submission Evaluation**
# * Submissions are evaluated on the [area under the ROC curve](http://en.wikipedia.org/wiki/Receiver_operating_characteristic) between the predicted probability and the observed target.
#
# <br>
#
# **Submission Restrictions**
# * **THIS IS A KERNELS ONLY COMPETITION**
#     * Submissions to this competition must be made through Notebooks.
#     * In order for the "Submit" button to be active after a commit, the following conditions must be met:
#         * *CPU Notebook <= 9 hours run-time*
#         * *GPU Notebook <= 9 hours run-time*
#         * *Internet access disabled*
#         * *Freely & publicly available external data is allowed, including pre-trained models*
#         * *Submission file must be named `submission.csv`*
#
# <br>
#
# **Submission File Format**
# * For each **`BraTS21ID`** in the test set, you must predict a probability for the target **`MGMT_value`**. The file should contain a header and have the following format:
# >```
# >BraTS21ID,MGMT_value
# >00001,0.5
# >00013,0.999
# >00015,0.1
# >etc.
# >```
#
# <br>
#
# ---
#
# <br>
#
# <b style="text-decoration: underline; font-family: Verdana;">COMPETITION TIMELINE</b>
#
# * **July 13, 2021** - Start Date.
# * **October 8, 2021** - Entry Deadline. You must accept the competition rules before this date in order to compete.
# * **October 8, 2021** - Team Merger Deadline. This is the last day participants may join or merge teams.
# * **October 15, 2021** - Final Submission Deadline.
# * **October 25, 2021** - Winners’ Requirements Deadline. This is the deadline for winners to submit to the host/Kaggle their training code, video, method description.
#
# > All deadlines are at 11:59 PM UTC on the corresponding day unless otherwise noted. The competition organizers reserve the right to update the contest timeline if they deem it necessary.

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">1.2  DATA DESCRIPTION</h2>
#
# ---
#
# <br>
#
# <b style="text-decoration: underline; font-family: Verdana;">DATA SPLITS/COHORTS</b>
#
# The competition data is defined by three cohorts: **Training**, **Validation (Public)**, and **Testing (Private)**.
# * The **“Training”** and the **“Validation”** cohorts are provided to the participants
# * The **“Testing”** cohort is kept hidden at all times, during and after the competition
#
# These 3 cohorts are structured as follows:
# * Each independent case has a **dedicated folder identified by a five-digit number**.
# * Within each of these **“case”** folders, there are four sub-folders
#     * Each of these **"case"** subfolders corresponds to each of the structural **m**ulti-**p**arametric **MRI** (**mpMRI**) scans, in **DICOM** format.
#     * The exact mpMRI scans included are:
#         * Fluid Attenuated Inversion Recovery (FLAIR)
#         * T1-weighted pre-contrast (T1w)
#         * T1-weighted post-contrast (T1Gd)
#         * T2-weighted (T2)
#
# Exact folder structure:
#
# ```
# Training/Validation/Testing
# │
# └─── 00000
# │   │
# │   └─── FLAIR
# │   │   │ Image-1.dcm
# │   │   │ Image-2.dcm
# │   │   │ ...
# │   │
# │   └─── T1w
# │   │   │ Image-1.dcm
# │   │   │ Image-2.dcm
# │   │   │ ...
# │   │
# │   └─── T1wCE
# │   │   │ Image-1.dcm
# │   │   │ Image-2.dcm
# │   │   │ ...
# │   │
# │   └─── T2w
# │   │   │ Image-1.dcm
# │   │   │ Image-2.dcm
# │   │   │ .....
# │
# └─── 00001
# │   │ ...
# │
# │ ...
# │
# └─── 00002
# │   │ ...
#
# ```
#
# <b style="text-decoration: underline; font-family: Verdana;">FILES</b>
#
# **`train/`**
# - folder containing the training files, with each top-level folder representing a subject
#
# **`train_labels.csv`**
# - file containing the target MGMT_value for each subject in the training data (e.g. the presence of MGMT promoter methylation)
#
# **`test/`**
# - the test files, which use the same structure as train/; your task is to predict the MGMT_value for each subject in the test data. NOTE: the total size of the rerun test set (Public and Private) is ~5x the size of the Public test set
#
# **`sample_submission.csv`**
# - a sample submission file in the correct format

# %% [markdown]
# <br>
#
# <a id="setup"></a>
#
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;" id="setup">2&nbsp;&nbsp;SETUP</h1>

# %%
ROOT_DIR = "/kaggle/input/rsna-miccai-brain-tumor-radiogenomic-classification"

TRAIN_DIR = os.path.join(ROOT_DIR, "train")
TEST_DIR = os.path.join(ROOT_DIR, "test")

SS_CSV = os.path.join(ROOT_DIR, "sample_submission.csv")
TRAIN_CSV = os.path.join(ROOT_DIR, "train_labels.csv")

train_df = pd.read_csv(TRAIN_CSV)
train_df["path_to_flair_dir"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_DIR, f"{x:>05}", "FLAIR"))
train_df["flair_image_count"] = train_df.path_to_flair_dir.progress_apply(lambda x: len(os.listdir(x)))
train_df["path_to_t1w_dir"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_DIR, f"{x:>05}", "T1w"))
train_df["t1w_image_count"] = train_df.path_to_t1w_dir.progress_apply(lambda x: len(os.listdir(x)))
train_df["path_to_t1wce_dir"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_DIR, f"{x:>05}", "T1wCE"))
train_df["t1wce_image_count"] = train_df.path_to_t1wce_dir.progress_apply(lambda x: len(os.listdir(x)))
train_df["path_to_t2w_dir"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_DIR, f"{x:>05}", "T2w"))
train_df["t2w_image_count"] = train_df.path_to_t2w_dir.progress_apply(lambda x: len(os.listdir(x)))
                                                                  
ss_df = pd.read_csv(SS_CSV)
ss_df["path_to_flair_dir"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_DIR, f"{x:>05}", "FLAIR"))
ss_df["flair_image_count"] = ss_df.path_to_flair_dir.progress_apply(lambda x: len(os.listdir(x)))
ss_df["path_to_t1w_dir"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_DIR, f"{x:>05}", "T1w"))
ss_df["t1w_image_count"] = ss_df.path_to_t1w_dir.progress_apply(lambda x: len(os.listdir(x)))
ss_df["path_to_t1wce_dir"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_DIR, f"{x:>05}", "T1wCE"))
ss_df["t1wce_image_count"] = ss_df.path_to_t1wce_dir.progress_apply(lambda x: len(os.listdir(x)))
ss_df["path_to_t2w_dir"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_DIR, f"{x:>05}", "T2w"))
ss_df["t2w_image_count"] = ss_df.path_to_t2w_dir.progress_apply(lambda x: len(os.listdir(x)))

print("\n\nTRAIN DATAFRAME\n")
display(train_df.head())

print("\n\n\nSAMPLE SUBMISSION DATAFRAME\n")
display(ss_df.head())

print("\nCOUNTS PER SCAN TYPE\n")
for c_name in [c for c in train_df.columns if "count" in c]:
    print(c_name, print(train_df[c_name].sum()))
# Out:
#   0%|          | 0/585 [00:00<?, ?it/s]
#   0%|          | 0/585 [00:00<?, ?it/s]
#   0%|          | 0/585 [00:00<?, ?it/s]
#   0%|          | 0/585 [00:00<?, ?it/s]
#   0%|          | 0/87 [00:00<?, ?it/s]
#   0%|          | 0/87 [00:00<?, ?it/s]
#   0%|          | 0/87 [00:00<?, ?it/s]
#   0%|          | 0/87 [00:00<?, ?it/s]
# TRAIN DATAFRAME
#    BraTS21ID  MGMT_value                                  path_to_flair_dir  \
# 0          0           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1          2           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2          3           0  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3          5           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4          6           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    flair_image_count                                    path_to_t1w_dir  \
# 0                400  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                400  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1w_image_count                                  path_to_t1wce_dir  \
# 0               33  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1               31  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2               33  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3               28  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1wce_image_count                                    path_to_t2w_dir  \
# 0                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t2w_image_count
# 0              408
# 1              384
# 2              408
# 3              424
# 4              408
# SAMPLE SUBMISSION DATAFRAME
#    BraTS21ID  MGMT_value                                  path_to_flair_dir  \
# 0          1         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1         13         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2         15         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3         27         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4         37         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    flair_image_count                                    path_to_t1w_dir  \
# 0                208  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                204  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1w_image_count                                  path_to_t1wce_dir  \
# 0               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1               30  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1wce_image_count                                    path_to_t2w_dir  \
# 0                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                304  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                304  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t2w_image_count
# 0              129
# 1              408
# 2              408
# 3              129
# 4              424
# COUNTS PER SCAN TYPE
#
# 74248
# flair_image_count None
# 77627
# t1w_image_count None
# 96766
# t1wce_image_count None
# 100000
# t2w_image_count None

# %% [markdown]
# <br>
#
# <a id="helper_functions"></a>
#
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;" id="helper_functions">3&nbsp;&nbsp;HELPER FUNCTIONS</h1>

# %%
def get_list_of_dcm_paths(dir_path):
    return sorted([os.path.join(dir_path, f_name) for f_name in os.listdir(dir_path)], key=lambda x: int(x.rsplit("-", 1)[1].split(".", 1)[0]))

def dicom2array(path, voi_lut=True, fix_monochrome=True):
    """ Convert dicom file to numpy array 
    
    Args:
        path (str): Path to the dicom file to be converted
        voi_lut (bool): Whether or not VOI LUT is available
        fix_monochrome (bool): Whether or not to apply monochrome fix
        
    Returns:
        Numpy array of the respective dicom file 
        
    """
    # Use the pydicom library to read the dicom file
    dicom = pydicom.read_file(path)
    
    # VOI LUT (if available by DICOM device) is used to 
    # transform raw DICOM data to "human-friendly" view
    if voi_lut:
        data = apply_voi_lut(dicom.pixel_array, dicom)
    else:
        data = dicom.pixel_array
        
    # The XRAY may look inverted
    #   - If we want to fix this we can
    if fix_monochrome and dicom.PhotometricInterpretation == "MONOCHROME1":
        data = np.amax(data) - data
    
    # Normalize the image array and return
    data = (data-np.min(data))/(np.max(data)-np.min(data))
    return data

def create_animation(np_arr):
    fig = plt.figure(figsize=(5, 5))
    plt.axis('off')
    im = plt.imshow(np_arr[..., 0], cmap="bone")
    plt.title("mpMRI Animation", fontweight="bold")
    def animate_func(i):
        im.set_array(np_arr[..., i])
        return [im]
    plt.close()
    return animation.FuncAnimation(fig, animate_func, frames = np_arr.shape[-1], interval = 1000//24)


def create_4scan_animation(flair_arr, t1w_arr, t1wce_arr, t2w_arr):
    
    def animate_func(i):
        flair_im.set_array(flair_arr[..., i])
        t1w_im.set_array(t1w_arr[..., i])
        t1wce_im.set_array(t1wce_arr[..., i])
        t2w_im.set_array(t2w_arr[..., i])
        return [flair_im, t1w_im, t1wce_im, t2w_im]
    
    fig = plt.figure(figsize=(18, 5))
    
    #
    plt.subplot(1,4,1)
    plt.axis('off')
    flair_im = plt.imshow(flair_arr[..., 0], cmap="bone")
    plt.title("FLAIR Animation", fontweight="bold")
    
    #
    plt.subplot(1,4,2)
    plt.axis('off')
    t1w_im = plt.imshow(t1w_arr[..., 0], cmap="bone")
    plt.title("T1w Animation", fontweight="bold")
    
    #
    plt.subplot(1,4,3)
    plt.axis('off')
    t1wce_im = plt.imshow(t1wce_arr[..., 0], cmap="bone")
    plt.title("T1wCE Animation", fontweight="bold")

    
    #
    plt.subplot(1,4,4)
    plt.axis('off')
    t2w_im = plt.imshow(t2w_arr[..., 0], cmap="bone")
    plt.title("T2w Animation", fontweight="bold")
    
    plt.close()
    
    return animation.FuncAnimation(fig, animate_func, frames = flair_arr.shape[-1], interval = 1000//16)


def get_dicom_meta(row, attrs):
    dcm_file = pydicom.read_file(row.dcm_path)
    for val in attrs:
        row[val] = dcm_file.get(val, None)
    return row


def load_npz(np_file_path, is_tf=False):
    if is_tf:
        return np.load(np_file_path.numpy().decode())["arr_0"] 
    else:
        return np.load(np_file_path)["arr_0"] 
    
    
def flatten_l_o_l(nested_list):
    """ Flatten a list of lists """
    return [item for sublist in nested_list for item in sublist]

# %% [markdown]
# <br>
#
# <a id="helper_functions"></a>
#
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;" id="dicom_understanding">4&nbsp;&nbsp;DICOM UNDERSTANDING</h1>

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">4.0 SET EXAMPLE PATIENT DATA</h2>
#
# ---
#
# <br>

# %%
EX_NUMBER = 0
EX_SLICE = 0
EX_PATIENT = train_df.iloc[EX_NUMBER]

ALL_DICOM_PATHS = glob(os.path.join(TRAIN_DIR, "**/*.dcm"), recursive=True)
FLAIR_DCM_PATHS = get_list_of_dcm_paths(EX_PATIENT["path_to_flair_dir"])
T1W_DCM_PATHS = get_list_of_dcm_paths(EX_PATIENT["path_to_t1w_dir"])
T1WCE_DCM_PATHS = get_list_of_dcm_paths(EX_PATIENT["path_to_t1wce_dir"])
T2W_DCM_PATHS = get_list_of_dcm_paths(EX_PATIENT["path_to_t2w_dir"])

FLAIR_EXAMPLE_DCM_1 = FLAIR_DCM_PATHS[EX_SLICE]
FLAIR_EXAMPLE_DCM_2 = FLAIR_DCM_PATHS[EX_SLICE+1]
T1W_EXAMPLE_DCM_1 = T1W_DCM_PATHS[EX_SLICE]
T1W_EXAMPLE_DCM_2 = T1W_DCM_PATHS[EX_SLICE+1]
T1WCE_EXAMPLE_DCM_1 = T1WCE_DCM_PATHS[EX_SLICE]
T1WCE_EXAMPLE_DCM_2 = T1WCE_DCM_PATHS[EX_SLICE+1]
T2W_EXAMPLE_DCM_1 = T2W_DCM_PATHS[EX_SLICE]
T2W_EXAMPLE_DCM_2 = T2W_DCM_PATHS[EX_SLICE+1]

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">4.1  BASIC STRUCTURE OF FLAIR DICOM</h2>
#
# ---
#
# <br>

# %%
flair_ex_dcm_1 = pydicom.read_file(FLAIR_EXAMPLE_DCM_1)
flair_ex_dcm_2 = pydicom.read_file(FLAIR_EXAMPLE_DCM_2)
FLAIR_ATTRS = flair_ex_dcm_1.dir()

print("FLAIR ATTRIBUTES:")
for k in FLAIR_ATTRS: print(f"\t--> {k:<30}( Same Across Dicoms = {str(flair_ex_dcm_1.get(k)==flair_ex_dcm_2.get(k)):<5} )")
# Out:
# FLAIR ATTRIBUTES:
# 	--> AccessionNumber               ( Same Across Dicoms = True  )
# 	--> AcquisitionMatrix             ( Same Across Dicoms = True  )
# 	--> BitsAllocated                 ( Same Across Dicoms = True  )
# 	--> BitsStored                    ( Same Across Dicoms = True  )
# 	--> Columns                       ( Same Across Dicoms = True  )
# 	--> EchoNumbers                   ( Same Across Dicoms = True  )
# 	--> EchoTime                      ( Same Across Dicoms = True  )
# 	--> EchoTrainLength               ( Same Across Dicoms = True  )
# 	--> FlipAngle                     ( Same Across Dicoms = True  )
# 	--> HighBit                       ( Same Across Dicoms = True  )
# 	--> ImageOrientationPatient       ( Same Across Dicoms = True  )
# 	--> ImagePositionPatient          ( Same Across Dicoms = False )
# 	--> ImageType                     ( Same Across Dicoms = True  )
# 	--> ImagedNucleus                 ( Same Across Dicoms = True  )
# 	--> ImagingFrequency              ( Same Across Dicoms = True  )
# 	--> InPlanePhaseEncodingDirection ( Same Across Dicoms = True  )
# 	--> InStackPositionNumber         ( Same Across Dicoms = True  )
# 	--> InstanceNumber                ( Same Across Dicoms = False )
# 	--> InversionTime                 ( Same Across Dicoms = True  )
# 	--> Laterality                    ( Same Across Dicoms = True  )
# 	--> MRAcquisitionType             ( Same Across Dicoms = True  )
# 	--> MagneticFieldStrength         ( Same Across Dicoms = True  )
# 	--> Modality                      ( Same Across Dicoms = True  )
# 	--> NumberOfAverages              ( Same Across Dicoms = True  )
# 	--> PatientID                     ( Same Across Dicoms = True  )
# 	--> PatientName                   ( Same Across Dicoms = True  )
# 	--> PatientPosition               ( Same Across Dicoms = True  )
# 	--> PercentPhaseFieldOfView       ( Same Across Dicoms = True  )
# 	--> PercentSampling               ( Same Across Dicoms = True  )
# 	--> PhotometricInterpretation     ( Same Across Dicoms = True  )
# 	--> PixelBandwidth                ( Same Across Dicoms = True  )
# 	--> PixelData                     ( Same Across Dicoms = True  )
# 	--> PixelRepresentation           ( Same Across Dicoms = True  )
# 	--> PixelSpacing                  ( Same Across Dicoms = True  )
# 	--> PositionReferenceIndicator    ( Same Across Dicoms = True  )
# 	--> ReconstructionDiameter        ( Same Across Dicoms = True  )
# 	--> RescaleIntercept              ( Same Across Dicoms = True  )
# 	--> RescaleSlope                  ( Same Across Dicoms = True  )
# 	--> RescaleType                   ( Same Across Dicoms = True  )
# 	--> Rows                          ( Same Across Dicoms = True  )
# 	--> SAR                           ( Same Across Dicoms = True  )
# 	--> SOPClassUID                   ( Same Across Dicoms = True  )
# 	--> SOPInstanceUID                ( Same Across Dicoms = False )
# 	--> SamplesPerPixel               ( Same Across Dicoms = True  )
# 	--> SeriesDescription             ( Same Across Dicoms = True  )
# 	--> SeriesInstanceUID             ( Same Across Dicoms = True  )
# 	--> SeriesNumber                  ( Same Across Dicoms = True  )
# 	--> SliceLocation                 ( Same Across Dicoms = False )
# 	--> SliceThickness                ( Same Across Dicoms = True  )
# 	--> SpacingBetweenSlices          ( Same Across Dicoms = True  )
# 	--> SpecificCharacterSet          ( Same Across Dicoms = True  )
# 	--> StudyInstanceUID              ( Same Across Dicoms = True  )
# 	--> TriggerWindow                 ( Same Across Dicoms = True  )
# 	--> WindowCenter                  ( Same Across Dicoms = False )
# 	--> WindowWidth                   ( Same Across Dicoms = False )

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">4.2  BASIC STRUCTURE OF T1W DICOM</h2>
#
# ---
#
# <br>

# %%
t1w_ex_dcm_1 = pydicom.read_file(T1W_EXAMPLE_DCM_1)
t1w_ex_dcm_2 = pydicom.read_file(T1W_EXAMPLE_DCM_2)
T1W_ATTRS = t1w_ex_dcm_1.dir()

print("T1W ATTRIBUTES:")
for k in T1W_ATTRS: print(f"\t--> {k:<30}( Same Across Two Dicoms = {str(t1w_ex_dcm_1.get(k)==t1w_ex_dcm_2.get(k)):<5} )")
# Out:
# T1W ATTRIBUTES:
# 	--> AccessionNumber               ( Same Across Two Dicoms = True  )
# 	--> AcquisitionMatrix             ( Same Across Two Dicoms = True  )
# 	--> BitsAllocated                 ( Same Across Two Dicoms = True  )
# 	--> BitsStored                    ( Same Across Two Dicoms = True  )
# 	--> Columns                       ( Same Across Two Dicoms = True  )
# 	--> EchoNumbers                   ( Same Across Two Dicoms = True  )
# 	--> EchoTime                      ( Same Across Two Dicoms = True  )
# 	--> EchoTrainLength               ( Same Across Two Dicoms = True  )
# 	--> FlipAngle                     ( Same Across Two Dicoms = True  )
# 	--> HighBit                       ( Same Across Two Dicoms = True  )
# 	--> ImageOrientationPatient       ( Same Across Two Dicoms = True  )
# 	--> ImagePositionPatient          ( Same Across Two Dicoms = False )
# 	--> ImageType                     ( Same Across Two Dicoms = True  )
# 	--> ImagedNucleus                 ( Same Across Two Dicoms = True  )
# 	--> ImagingFrequency              ( Same Across Two Dicoms = True  )
# 	--> InPlanePhaseEncodingDirection ( Same Across Two Dicoms = True  )
# 	--> InStackPositionNumber         ( Same Across Two Dicoms = False )
# 	--> InstanceNumber                ( Same Across Two Dicoms = False )
# 	--> Laterality                    ( Same Across Two Dicoms = True  )
# 	--> MRAcquisitionType             ( Same Across Two Dicoms = True  )
# 	--> MagneticFieldStrength         ( Same Across Two Dicoms = True  )
# 	--> Modality                      ( Same Across Two Dicoms = True  )
# 	--> NumberOfAverages              ( Same Across Two Dicoms = True  )
# 	--> PatientID                     ( Same Across Two Dicoms = True  )
# 	--> PatientName                   ( Same Across Two Dicoms = True  )
# 	--> PatientPosition               ( Same Across Two Dicoms = True  )
# 	--> PercentPhaseFieldOfView       ( Same Across Two Dicoms = True  )
# 	--> PercentSampling               ( Same Across Two Dicoms = True  )
# 	--> PhotometricInterpretation     ( Same Across Two Dicoms = True  )
# 	--> PixelBandwidth                ( Same Across Two Dicoms = True  )
# 	--> PixelData                     ( Same Across Two Dicoms = True  )
# 	--> PixelRepresentation           ( Same Across Two Dicoms = True  )
# 	--> PixelSpacing                  ( Same Across Two Dicoms = True  )
# 	--> PositionReferenceIndicator    ( Same Across Two Dicoms = True  )
# 	--> ReconstructionDiameter        ( Same Across Two Dicoms = True  )
# 	--> RescaleIntercept              ( Same Across Two Dicoms = True  )
# 	--> RescaleSlope                  ( Same Across Two Dicoms = True  )
# 	--> RescaleType                   ( Same Across Two Dicoms = True  )
# 	--> Rows                          ( Same Across Two Dicoms = True  )
# 	--> SAR                           ( Same Across Two Dicoms = True  )
# 	--> SOPClassUID                   ( Same Across Two Dicoms = True  )
# 	--> SOPInstanceUID                ( Same Across Two Dicoms = False )
# 	--> SamplesPerPixel               ( Same Across Two Dicoms = True  )
# 	--> SeriesDescription             ( Same Across Two Dicoms = True  )
# 	--> SeriesInstanceUID             ( Same Across Two Dicoms = True  )
# 	--> SeriesNumber                  ( Same Across Two Dicoms = True  )
# 	--> SliceLocation                 ( Same Across Two Dicoms = False )
# 	--> SliceThickness                ( Same Across Two Dicoms = True  )
# 	--> SpacingBetweenSlices          ( Same Across Two Dicoms = True  )
# 	--> SpecificCharacterSet          ( Same Across Two Dicoms = True  )
# 	--> StudyInstanceUID              ( Same Across Two Dicoms = True  )
# 	--> TriggerWindow                 ( Same Across Two Dicoms = True  )
# 	--> WindowCenter                  ( Same Across Two Dicoms = False )
# 	--> WindowWidth                   ( Same Across Two Dicoms = False )

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">4.3  BASIC STRUCTURE OF T1WCE DICOM</h2>
#
# ---
#
# <br>
#
# This dicom has an additional two fields that the other dicoms don't have:
# * **`InPlanePhaseEncodingDirection`**
# * **`InStackPositionNumber`**

# %%
t1wce_ex_dcm_1 = pydicom.read_file(T1WCE_EXAMPLE_DCM_1)
t1wce_ex_dcm_2 = pydicom.read_file(T1WCE_EXAMPLE_DCM_2)
T1WCE_ATTRS = t1wce_ex_dcm_1.dir()

print("T1WCE ATTRIBUTES:")
for k in T1WCE_ATTRS: print(f"\t--> {k:<30}( Same Across Two Dicoms = {str(t1wce_ex_dcm_1.get(k)==t1wce_ex_dcm_2.get(k)):<5} )")
# Out:
# T1WCE ATTRIBUTES:
# 	--> AccessionNumber               ( Same Across Two Dicoms = True  )
# 	--> AcquisitionMatrix             ( Same Across Two Dicoms = True  )
# 	--> BitsAllocated                 ( Same Across Two Dicoms = True  )
# 	--> BitsStored                    ( Same Across Two Dicoms = True  )
# 	--> Columns                       ( Same Across Two Dicoms = True  )
# 	--> EchoNumbers                   ( Same Across Two Dicoms = True  )
# 	--> EchoTime                      ( Same Across Two Dicoms = True  )
# 	--> EchoTrainLength               ( Same Across Two Dicoms = True  )
# 	--> FlipAngle                     ( Same Across Two Dicoms = True  )
# 	--> HighBit                       ( Same Across Two Dicoms = True  )
# 	--> ImageOrientationPatient       ( Same Across Two Dicoms = True  )
# 	--> ImagePositionPatient          ( Same Across Two Dicoms = False )
# 	--> ImageType                     ( Same Across Two Dicoms = True  )
# 	--> ImagedNucleus                 ( Same Across Two Dicoms = True  )
# 	--> ImagingFrequency              ( Same Across Two Dicoms = True  )
# 	--> InstanceNumber                ( Same Across Two Dicoms = False )
# 	--> InversionTime                 ( Same Across Two Dicoms = True  )
# 	--> Laterality                    ( Same Across Two Dicoms = True  )
# 	--> MRAcquisitionType             ( Same Across Two Dicoms = True  )
# 	--> MagneticFieldStrength         ( Same Across Two Dicoms = True  )
# 	--> Modality                      ( Same Across Two Dicoms = True  )
# 	--> NumberOfAverages              ( Same Across Two Dicoms = True  )
# 	--> PatientID                     ( Same Across Two Dicoms = True  )
# 	--> PatientName                   ( Same Across Two Dicoms = True  )
# 	--> PatientPosition               ( Same Across Two Dicoms = True  )
# 	--> PercentPhaseFieldOfView       ( Same Across Two Dicoms = True  )
# 	--> PercentSampling               ( Same Across Two Dicoms = True  )
# 	--> PhotometricInterpretation     ( Same Across Two Dicoms = True  )
# 	--> PixelBandwidth                ( Same Across Two Dicoms = True  )
# 	--> PixelData                     ( Same Across Two Dicoms = True  )
# 	--> PixelRepresentation           ( Same Across Two Dicoms = True  )
# 	--> PixelSpacing                  ( Same Across Two Dicoms = True  )
# 	--> PositionReferenceIndicator    ( Same Across Two Dicoms = True  )
# 	--> ReconstructionDiameter        ( Same Across Two Dicoms = True  )
# 	--> RescaleIntercept              ( Same Across Two Dicoms = True  )
# 	--> RescaleSlope                  ( Same Across Two Dicoms = True  )
# 	--> RescaleType                   ( Same Across Two Dicoms = True  )
# 	--> Rows                          ( Same Across Two Dicoms = True  )
# 	--> SAR                           ( Same Across Two Dicoms = True  )
# 	--> SOPClassUID                   ( Same Across Two Dicoms = True  )
# 	--> SOPInstanceUID                ( Same Across Two Dicoms = False )
# 	--> SamplesPerPixel               ( Same Across Two Dicoms = True  )
# 	--> SeriesDescription             ( Same Across Two Dicoms = True  )
# 	--> SeriesInstanceUID             ( Same Across Two Dicoms = True  )
# 	--> SeriesNumber                  ( Same Across Two Dicoms = True  )
# 	--> SliceLocation                 ( Same Across Two Dicoms = False )
# 	--> SliceThickness                ( Same Across Two Dicoms = True  )
# 	--> SpacingBetweenSlices          ( Same Across Two Dicoms = True  )
# 	--> SpecificCharacterSet          ( Same Across Two Dicoms = True  )
# 	--> StudyInstanceUID              ( Same Across Two Dicoms = True  )
# 	--> TriggerWindow                 ( Same Across Two Dicoms = True  )
# 	--> WindowCenter                  ( Same Across Two Dicoms = False )
# 	--> WindowWidth                   ( Same Across Two Dicoms = False )

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">4.4  BASIC STRUCTURE OF T2W DICOM</h2>
#
# ---
#
# <br>

# %%
t2w_ex_dcm_1 = pydicom.read_file(T2W_EXAMPLE_DCM_1)
t2w_ex_dcm_2 = pydicom.read_file(T2W_EXAMPLE_DCM_2)
T2W_ATTRS = t2w_ex_dcm_1.dir()

print("T2W ATTRIBUTES:")
for k in T2W_ATTRS: print(f"\t--> {k:<30}( Same Across Two Dicoms = {str(t2w_ex_dcm_1.get(k)==t2w_ex_dcm_2.get(k)):<5} )")
# Out:
# T2W ATTRIBUTES:
# 	--> AccessionNumber               ( Same Across Two Dicoms = True  )
# 	--> AcquisitionMatrix             ( Same Across Two Dicoms = True  )
# 	--> BitsAllocated                 ( Same Across Two Dicoms = True  )
# 	--> BitsStored                    ( Same Across Two Dicoms = True  )
# 	--> Columns                       ( Same Across Two Dicoms = True  )
# 	--> EchoNumbers                   ( Same Across Two Dicoms = True  )
# 	--> EchoTime                      ( Same Across Two Dicoms = True  )
# 	--> EchoTrainLength               ( Same Across Two Dicoms = True  )
# 	--> FlipAngle                     ( Same Across Two Dicoms = True  )
# 	--> HighBit                       ( Same Across Two Dicoms = True  )
# 	--> ImageOrientationPatient       ( Same Across Two Dicoms = True  )
# 	--> ImagePositionPatient          ( Same Across Two Dicoms = False )
# 	--> ImageType                     ( Same Across Two Dicoms = True  )
# 	--> ImagedNucleus                 ( Same Across Two Dicoms = True  )
# 	--> ImagingFrequency              ( Same Across Two Dicoms = True  )
# 	--> InPlanePhaseEncodingDirection ( Same Across Two Dicoms = True  )
# 	--> InStackPositionNumber         ( Same Across Two Dicoms = True  )
# 	--> InstanceNumber                ( Same Across Two Dicoms = False )
# 	--> Laterality                    ( Same Across Two Dicoms = True  )
# 	--> MRAcquisitionType             ( Same Across Two Dicoms = True  )
# 	--> MagneticFieldStrength         ( Same Across Two Dicoms = True  )
# 	--> Modality                      ( Same Across Two Dicoms = True  )
# 	--> NumberOfAverages              ( Same Across Two Dicoms = True  )
# 	--> PatientID                     ( Same Across Two Dicoms = True  )
# 	--> PatientName                   ( Same Across Two Dicoms = True  )
# 	--> PatientPosition               ( Same Across Two Dicoms = True  )
# 	--> PercentPhaseFieldOfView       ( Same Across Two Dicoms = True  )
# 	--> PercentSampling               ( Same Across Two Dicoms = True  )
# 	--> PhotometricInterpretation     ( Same Across Two Dicoms = True  )
# 	--> PixelBandwidth                ( Same Across Two Dicoms = True  )
# 	--> PixelData                     ( Same Across Two Dicoms = True  )
# 	--> PixelRepresentation           ( Same Across Two Dicoms = True  )
# 	--> PixelSpacing                  ( Same Across Two Dicoms = True  )
# 	--> PositionReferenceIndicator    ( Same Across Two Dicoms = True  )
# 	--> ReconstructionDiameter        ( Same Across Two Dicoms = True  )
# 	--> RescaleIntercept              ( Same Across Two Dicoms = True  )
# 	--> RescaleSlope                  ( Same Across Two Dicoms = True  )
# 	--> RescaleType                   ( Same Across Two Dicoms = True  )
# 	--> Rows                          ( Same Across Two Dicoms = True  )
# 	--> SAR                           ( Same Across Two Dicoms = True  )
# 	--> SOPClassUID                   ( Same Across Two Dicoms = True  )
# 	--> SOPInstanceUID                ( Same Across Two Dicoms = False )
# 	--> SamplesPerPixel               ( Same Across Two Dicoms = True  )
# 	--> SeriesDescription             ( Same Across Two Dicoms = True  )
# 	--> SeriesInstanceUID             ( Same Across Two Dicoms = True  )
# 	--> SeriesNumber                  ( Same Across Two Dicoms = True  )
# 	--> SliceLocation                 ( Same Across Two Dicoms = False )
# 	--> SliceThickness                ( Same Across Two Dicoms = True  )
# 	--> SpacingBetweenSlices          ( Same Across Two Dicoms = True  )
# 	--> SpecificCharacterSet          ( Same Across Two Dicoms = True  )
# 	--> StudyInstanceUID              ( Same Across Two Dicoms = True  )
# 	--> TriggerWindow                 ( Same Across Two Dicoms = True  )
# 	--> WindowCenter                  ( Same Across Two Dicoms = False )
# 	--> WindowWidth                   ( Same Across Two Dicoms = False )

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">4.5  CAPTURE ALL OPTIONS AND VALUE COUNTS FOR DICOM</h2>
#
# ---
#
# <br>
#
# We will not be capturing dicom metadata for UIDs or PixelData (this would cause OOM issues).
#
# <div class="alert alert-block alert-danger" style="margin: 2em; line-height: 1.7em; font-family: Verdana;">
#     <br><center><b style="font-size: 16px;">⏱⏱⏱ &nbsp; NOTE: THIS CELL WILL TAKE ~15 MINUTES TO RUN  &nbsp; ⏱⏱⏱</b></center><br>
# </div>

# %%
t1 = time.time()

DESIRED_ATTRS = [x for x in T1WCE_ATTRS if (x!="PixelData" and "UID" not in x)]
dicom_df = pd.DataFrame({"dcm_path":ALL_DICOM_PATHS})
dicom_df = dicom_df.reindex(columns=(["dcm_path",]+DESIRED_ATTRS))

print(f"\n ... Processing Started...")

# Regular method
#    - for 10,000 dicom files the regular takes 94.639 seconds
#    - processing will take (350000/10000)*94.639 ~= 3325 seconds ~= 56 minutes (actual is 71 minutes)

##### dicom_df = dicom_df.progress_apply(lambda x: get_dicom_meta(x, DESIRED_ATTRS), axis=1)

# Use Multiprocessing (Pandarallel)
#    - no progress bar but approximately 3.75 times faster
#    - for 10,000 dicom files pandarallel takes 25.529 seconds
#    - processing will take (350000/10000)*25.529 ~= 893 seconds ~= 15 minutes (actual is 19 minutes)
dicom_df = dicom_df.parallel_apply(lambda x: get_dicom_meta(x, DESIRED_ATTRS), axis=1)

print(f"... Processing Completed in  >>>>> {time.time()-t1} <<<<<  Seconds ...\n")

display(dicom_df)
# Out:
#  ... Processing Started...
# ... Processing Completed in  >>>>> 2050.2977697849274 <<<<<  Seconds ...
#                                                  dcm_path AccessionNumber  \
# 0       /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00688
# 1       /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00688
# 2       /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00688
# 3       /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00688
# 4       /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00688
# ...                                                   ...             ...
# 348636  /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00049
# 348637  /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00049
# 348638  /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00049
# 348639  /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00049
# 348640  /kaggle/input/rsna-miccai-brain-tumor-radiogen...           00049
#
#        AcquisitionMatrix  BitsAllocated  BitsStored  Columns  EchoNumbers  \
# 0       [0, 288, 288, 0]             16          16      512          1.0
# 1       [0, 288, 288, 0]             16          16      512          1.0
# 2       [0, 288, 288, 0]             16          16      512          1.0
# 3       [0, 288, 288, 0]             16          16      512          1.0
# 4       [0, 288, 288, 0]             16          16      512          1.0
# ...                  ...            ...         ...      ...          ...
# 348636  [0, 224, 224, 0]             16          16      512          1.0
# 348637  [0, 224, 224, 0]             16          16      512          1.0
# 348638  [0, 224, 224, 0]             16          16      512          1.0
# 348639  [0, 224, 224, 0]             16          16      512          1.0
# 348640  [0, 224, 224, 0]             16          16      512          1.0
#
#        EchoTime  EchoTrainLength  FlipAngle  HighBit  \
# 0          None            140.0       90.0       15
# 1          None            140.0       90.0       15
# 2          None            140.0       90.0       15
# 3          None            140.0       90.0       15
# 4          None            140.0       90.0       15
# ...         ...              ...        ...      ...
# 348636     None            124.0       90.0       15
# 348637     None            124.0       90.0       15
# 348638     None            124.0       90.0       15
# 348639     None            124.0       90.0       15
# 348640     None            124.0       90.0       15
#
#                                   ImageOrientationPatient  \
# 0                       [0.03649, 0.99933, 0, -0, -0, -1]
# 1                       [0.03649, 0.99933, 0, -0, -0, -1]
# 2                       [0.03649, 0.99933, 0, -0, -0, -1]
# 3                       [0.03649, 0.99933, 0, -0, -0, -1]
# 4                       [0.03649, 0.99933, 0, -0, -0, -1]
# ...                                                   ...
# 348636  [0.99788, -0.00495468, 0.0648889, 0.0650777, 0...
# 348637  [0.99788, -0.00495468, 0.0648889, 0.0650777, 0...
# 348638  [0.99788, -0.00495468, 0.0648888, 0.0650777, 0...
# 348639  [0.99788, -0.00495468, 0.0648888, 0.0650777, 0...
# 348640  [0.99788, -0.00495468, 0.0648888, 0.0650777, 0...
#
#                  ImagePositionPatient             ImageType ImagedNucleus  \
# 0       [-47.7591, -155.489, 124.626]  [DERIVED, SECONDARY]            1H
# 1           [-33.7685, -156, 124.626]  [DERIVED, SECONDARY]            1H
# 2        [-93.7285, -153.81, 124.626]  [DERIVED, SECONDARY]            1H
# 3        [23.6932, -158.098, 124.626]  [DERIVED, SECONDARY]            1H
# 4        [39.6826, -158.682, 124.626]  [DERIVED, SECONDARY]            1H
# ...                               ...                   ...           ...
# 348636   [-147.57, -17.6302, 118.846]  [DERIVED, SECONDARY]            1H
# 348637    [-147.57, 11.6844, 121.084]  [DERIVED, SECONDARY]            1H
# 348638    [-147.57, -25.3079, 118.26]  [DERIVED, SECONDARY]            1H
# 348639     [-147.57, 31.9255, 122.63]  [DERIVED, SECONDARY]            1H
# 348640   [-147.57, -63.6961, 115.329]  [DERIVED, SECONDARY]            1H
#
#         ImagingFrequency  InstanceNumber InversionTime Laterality  \
# 0             127.801648             273          None
# 1             127.801648             245          None
# 2             127.801648             365          None
# 3             127.801648             130          None
# 4             127.801648              98          None
# ...                  ...             ...           ...        ...
# 348636         63.854262             102          None
# 348637         63.854262              60          None
# 348638         63.854262             113          None
# 348639         63.854262              31          None
# 348640         63.854262             168          None
#
#        MRAcquisitionType  MagneticFieldStrength Modality  NumberOfAverages  \
# 0                     3D                    3.0       MR               1.0
# 1                     3D                    3.0       MR               1.0
# 2                     3D                    3.0       MR               1.0
# 3                     3D                    3.0       MR               1.0
# 4                     3D                    3.0       MR               1.0
# ...                  ...                    ...      ...               ...
# 348636                3D                    1.5       MR               1.0
# 348637                3D                    1.5       MR               1.0
# 348638                3D                    1.5       MR               1.0
# 348639                3D                    1.5       MR               1.0
# 348640                3D                    1.5       MR               1.0
#
#        PatientID      PatientName PatientPosition  PercentPhaseFieldOfView  \
# 0          00688  (0, 0, 6, 8, 8)             HFS                     90.0
# 1          00688  (0, 0, 6, 8, 8)             HFS                     90.0
# 2          00688  (0, 0, 6, 8, 8)             HFS                     90.0
# 3          00688  (0, 0, 6, 8, 8)             HFS                     90.0
# 4          00688  (0, 0, 6, 8, 8)             HFS                     90.0
# ...          ...              ...             ...                      ...
# 348636     00049  (0, 0, 0, 4, 9)             HFS                     80.0
# 348637     00049  (0, 0, 0, 4, 9)             HFS                     80.0
# 348638     00049  (0, 0, 0, 4, 9)             HFS                     80.0
# 348639     00049  (0, 0, 0, 4, 9)             HFS                     80.0
# 348640     00049  (0, 0, 0, 4, 9)             HFS                     80.0
#
#         PercentSampling PhotometricInterpretation  PixelBandwidth  \
# 0                 100.0               MONOCHROME2        244.1410
# 1                 100.0               MONOCHROME2        244.1410
# 2                 100.0               MONOCHROME2        244.1410
# 3                 100.0               MONOCHROME2        244.1410
# 4                 100.0               MONOCHROME2        244.1410
# ...                 ...                       ...             ...
# 348636            100.0               MONOCHROME2         65.1172
# 348637            100.0               MONOCHROME2         65.1172
# 348638            100.0               MONOCHROME2         65.1172
# 348639            100.0               MONOCHROME2         65.1172
# 348640            100.0               MONOCHROME2         65.1172
#
#         PixelRepresentation                            PixelSpacing  \
# 0                         1                              [0.5, 0.5]
# 1                         1                              [0.5, 0.5]
# 2                         1                              [0.5, 0.5]
# 3                         1                              [0.5, 0.5]
# 4                         1                              [0.5, 0.5]
# ...                     ...                                     ...
# 348636                    1  [0.539099991321564, 0.539099991321564]
# 348637                    1  [0.539099991321564, 0.539099991321564]
# 348638                    1  [0.539099991321564, 0.539099991321564]
# 348639                    1  [0.539099991321564, 0.539099991321564]
# 348640                    1  [0.539099991321564, 0.539099991321564]
#
#        PositionReferenceIndicator  ReconstructionDiameter  RescaleIntercept  \
# 0                                                   256.0               0.0
# 1                                                   256.0               0.0
# 2                                                   256.0               0.0
# 3                                                   256.0               0.0
# 4                                                   256.0               0.0
# ...                           ...                     ...               ...
# 348636                                              276.0               0.0
# 348637                                              276.0               0.0
# 348638                                              276.0               0.0
# 348639                                              276.0               0.0
# 348640                                              276.0               0.0
#
#         RescaleSlope RescaleType  Rows       SAR  SamplesPerPixel  \
# 0                1.0          US   512  0.426900                1
# 1                1.0          US   512  0.426900                1
# 2                1.0          US   512  0.426900                1
# 3                1.0          US   512  0.426900                1
# 4                1.0          US   512  0.426900                1
# ...              ...         ...   ...       ...              ...
# 348636           1.0          US   512  0.241698                1
# 348637           1.0          US   512  0.241698                1
# 348638           1.0          US   512  0.241698                1
# 348639           1.0          US   512  0.241698                1
# 348640           1.0          US   512  0.241698                1
#
#        SeriesDescription  SeriesNumber  SliceLocation  SliceThickness  \
# 0                    T2w             6      43.097221             1.0
# 1                    T2w             6      29.106564             1.0
# 2                    T2w             6      89.066612             1.0
# 3                    T2w             6     -28.355152             1.0
# 4                    T2w             6     -44.344479             1.0
# ...                  ...           ...            ...             ...
# 348636             FLAIR             5       7.848782             1.4
# 348637             FLAIR             5     -21.465889             1.4
# 348638             FLAIR             5      15.526436             1.4
# 348639             FLAIR             5     -41.706963             1.4
# 348640             FLAIR             5      53.914673             1.4
#
#         SpacingBetweenSlices SpecificCharacterSet  TriggerWindow WindowCenter  \
# 0                        1.0           ISO_IR 100            0.0          762
# 1                        1.0           ISO_IR 100            0.0          821
# 2                        1.0           ISO_IR 100            0.0          216
# 3                        1.0           ISO_IR 100            0.0          780
# 4                        1.0           ISO_IR 100            0.0          655
# ...                      ...                  ...            ...          ...
# 348636                   1.0           ISO_IR 100            0.0          317
# 348637                   1.0           ISO_IR 100            0.0          335
# 348638                   1.0           ISO_IR 100            0.0          453
# 348639                   1.0           ISO_IR 100            0.0          275
# 348640                   1.0           ISO_IR 100            0.0          421
#
#        WindowWidth
# 0             1525
# 1             1642
# 2              432
# 3             1560
# 4             1311
# ...            ...
# 348636         634
# 348637         671
# 348638         906
# 348639         550
# 348640         842
#
# [348641 rows x 49 columns]

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">4.6  PERFORM ANALYSIS ON EACH COLUMN</h2>
#
# ---
#
# We will first identify all of the possible values (including NaN) for a given attribute as well as their respective occurence counts.

# %%
for attr in DESIRED_ATTRS:
    print(f"\n\nAttribute Name: {attr} ({dicom_df[attr].astype(str).nunique()} Different Values)\n")
    for i, (k,v) in enumerate(dicom_df[attr].astype(str).value_counts(dropna=False).items()): 
        print(f"\t{repr(k):<50} --> Occurs {v} Times In Training Data")
        if i == 10:
            print("\n\t--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------")
            break
# Out:
# Attribute Name: AccessionNumber (585 Different Values)
#
# 	'00747'                                            --> Occurs 1372 Times In Training Data
# 	'00691'                                            --> Occurs 1350 Times In Training Data
# 	'00558'                                            --> Occurs 1312 Times In Training Data
# 	'00723'                                            --> Occurs 1254 Times In Training Data
# 	'00504'                                            --> Occurs 1240 Times In Training Data
# 	'00705'                                            --> Occurs 1224 Times In Training Data
# 	'00730'                                            --> Occurs 1195 Times In Training Data
# 	'00615'                                            --> Occurs 1190 Times In Training Data
# 	'00012'                                            --> Occurs 1183 Times In Training Data
# 	'00491'                                            --> Occurs 1167 Times In Training Data
# 	'00554'                                            --> Occurs 1148 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: AcquisitionMatrix (112 Different Values)
#
# 	'[0, 256, 256, 0]'                                 --> Occurs 212190 Times In Training Data
# 	'[0, 256, 192, 0]'                                 --> Occurs 77378 Times In Training Data
# 	'[0, 288, 288, 0]'                                 --> Occurs 15363 Times In Training Data
# 	'[0, 256, 208, 0]'                                 --> Occurs 10894 Times In Training Data
# 	'[0, 320, 224, 0]'                                 --> Occurs 4727 Times In Training Data
# 	'[0, 256, 224, 0]'                                 --> Occurs 2794 Times In Training Data
# 	'[0, 224, 224, 0]'                                 --> Occurs 2778 Times In Training Data
# 	'[0, 268, 268, 0]'                                 --> Occurs 1720 Times In Training Data
# 	'[0, 320, 192, 0]'                                 --> Occurs 1519 Times In Training Data
# 	'[0, 256, 232, 0]'                                 --> Occurs 1468 Times In Training Data
# 	'None'                                             --> Occurs 1402 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: BitsAllocated (1 Different Values)
#
# 	'16'                                               --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: BitsStored (1 Different Values)
#
# 	'16'                                               --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: Columns (36 Different Values)
#
# 	'512'                                              --> Occurs 181544 Times In Training Data
# 	'192'                                              --> Occurs 69350 Times In Training Data
# 	'256'                                              --> Occurs 68551 Times In Training Data
# 	'208'                                              --> Occurs 10841 Times In Training Data
# 	'384'                                              --> Occurs 7320 Times In Training Data
# 	'448'                                              --> Occurs 2250 Times In Training Data
# 	'320'                                              --> Occurs 1447 Times In Training Data
# 	'232'                                              --> Occurs 1408 Times In Training Data
# 	'416'                                              --> Occurs 1005 Times In Training Data
# 	'224'                                              --> Occurs 740 Times In Training Data
# 	'260'                                              --> Occurs 659 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: EchoNumbers (4 Different Values)
#
# 	'1.0'                                              --> Occurs 345521 Times In Training Data
# 	'nan'                                              --> Occurs 2474 Times In Training Data
# 	'0.0'                                              --> Occurs 350 Times In Training Data
# 	'2.0'                                              --> Occurs 296 Times In Training Data
#
#
# Attribute Name: EchoTime (1 Different Values)
#
# 	'None'                                             --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: EchoTrainLength (63 Different Values)
#
# 	'1.0'                                              --> Occurs 173961 Times In Training Data
# 	'200.0'                                            --> Occurs 27344 Times In Training Data
# 	'110.0'                                            --> Occurs 26160 Times In Training Data
# 	'142.0'                                            --> Occurs 25365 Times In Training Data
# 	'140.0'                                            --> Occurs 17314 Times In Training Data
# 	'160.0'                                            --> Occurs 16041 Times In Training Data
# 	'15.0'                                             --> Occurs 12440 Times In Training Data
# 	'13.0'                                             --> Occurs 9865 Times In Training Data
# 	'108.0'                                            --> Occurs 3896 Times In Training Data
# 	'164.0'                                            --> Occurs 2846 Times In Training Data
# 	'162.0'                                            --> Occurs 2278 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: FlipAngle (61 Different Values)
#
# 	'90.0'                                             --> Occurs 151888 Times In Training Data
# 	'12.0'                                             --> Occurs 76502 Times In Training Data
# 	'15.0'                                             --> Occurs 71167 Times In Training Data
# 	'160.0'                                            --> Occurs 10802 Times In Training Data
# 	'170.0'                                            --> Occurs 7388 Times In Training Data
# 	'9.0'                                              --> Occurs 6390 Times In Training Data
# 	'150.0'                                            --> Occurs 4011 Times In Training Data
# 	'20.0'                                             --> Occurs 2990 Times In Training Data
# 	'8.0'                                              --> Occurs 2880 Times In Training Data
# 	'13.0'                                             --> Occurs 1386 Times In Training Data
# 	'73.0'                                             --> Occurs 1308 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: HighBit (1 Different Values)
#
# 	'15'                                               --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: ImageOrientationPatient (1753 Different Values)
#
# 	'[0.9999984769134, -0.0017453283007, 0, 0.00174532830068, 0.9999984769134, 0]' --> Occurs 73671 Times In Training Data
# 	'[1, -0, 0, -0, 1, 0]'                             --> Occurs 43966 Times In Training Data
# 	'[-0, 1, 0, -0, -0, -1]'                           --> Occurs 21017 Times In Training Data
# 	'[1, -0, 0, -0, -0, -1]'                           --> Occurs 15832 Times In Training Data
# 	'[1, -2.051034e-10, 0, 2.051034e-10, 1, 0]'        --> Occurs 6629 Times In Training Data
# 	'[1, -2.05103e-10, 0, 2.05103e-10, 1, 0]'          --> Occurs 6004 Times In Training Data
# 	'[1, 0, 0, 0, 1, 0]'                               --> Occurs 4451 Times In Training Data
# 	'[1, 4.897e-12, 0, -4.897e-12, 1, 0]'              --> Occurs 1528 Times In Training Data
# 	'[1, -1.1103e-11, 4e-06, -4.897e-12, 1, 4e-06]'    --> Occurs 1072 Times In Training Data
# 	'[0.14926, 0.9888, 0, -0, -0, -1]'                 --> Occurs 776 Times In Training Data
# 	'[0.999998477, -0.0017453283, 0, 0.0017453283, 0.999998477, 0]' --> Occurs 768 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: ImagePositionPatient (282480 Different Values)
#
# 	'[-120, -122.927, -25.1707]'                       --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, 55.8293]'                        --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, 25.8293]'                        --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, 58.8293]'                        --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, 28.8293]'                        --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, -46.1707]'                       --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, 67.8293]'                        --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, -49.1707]'                       --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, -28.1707]'                       --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, -73.1707]'                       --> Occurs 5 Times In Training Data
# 	'[-120, -122.927, -37.1707]'                       --> Occurs 5 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: ImageType (1 Different Values)
#
# 	"['DERIVED', 'SECONDARY']"                         --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: ImagedNucleus (4 Different Values)
#
# 	'1H'                                               --> Occurs 344636 Times In Training Data
# 	'H1'                                               --> Occurs 2577 Times In Training Data
# 	'None'                                             --> Occurs 1214 Times In Training Data
# 	'H'                                                --> Occurs 214 Times In Training Data
#
#
# Attribute Name: ImagingFrequency (1138 Different Values)
#
# 	'127.757656'                                       --> Occurs 2308 Times In Training Data
# 	'127.742287'                                       --> Occurs 1815 Times In Training Data
# 	'127.742344'                                       --> Occurs 1762 Times In Training Data
# 	'127.742313'                                       --> Occurs 1746 Times In Training Data
# 	'127.742339'                                       --> Occurs 1726 Times In Training Data
# 	'127.742293'                                       --> Occurs 1686 Times In Training Data
# 	'127.742286'                                       --> Occurs 1662 Times In Training Data
# 	'127.742311'                                       --> Occurs 1642 Times In Training Data
# 	'127.742279'                                       --> Occurs 1624 Times In Training Data
# 	'127.742308'                                       --> Occurs 1604 Times In Training Data
# 	'127.742356'                                       --> Occurs 1591 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: InstanceNumber (516 Different Values)
#
# 	'9'                                                --> Occurs 2274 Times In Training Data
# 	'17'                                               --> Occurs 2274 Times In Training Data
# 	'11'                                               --> Occurs 2273 Times In Training Data
# 	'5'                                                --> Occurs 2273 Times In Training Data
# 	'1'                                                --> Occurs 2273 Times In Training Data
# 	'10'                                               --> Occurs 2273 Times In Training Data
# 	'15'                                               --> Occurs 2273 Times In Training Data
# 	'16'                                               --> Occurs 2273 Times In Training Data
# 	'19'                                               --> Occurs 2273 Times In Training Data
# 	'4'                                                --> Occurs 2273 Times In Training Data
# 	'13'                                               --> Occurs 2273 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: InversionTime (1 Different Values)
#
# 	'None'                                             --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: Laterality (2 Different Values)
#
# 	''                                                 --> Occurs 244392 Times In Training Data
# 	'None'                                             --> Occurs 104249 Times In Training Data
#
#
# Attribute Name: MRAcquisitionType (4 Different Values)
#
# 	'3D'                                               --> Occurs 303664 Times In Training Data
# 	'2D'                                               --> Occurs 43449 Times In Training Data
# 	'None'                                             --> Occurs 1214 Times In Training Data
# 	''                                                 --> Occurs 314 Times In Training Data
#
#
# Attribute Name: MagneticFieldStrength (7 Different Values)
#
# 	'3.0'                                              --> Occurs 323035 Times In Training Data
# 	'1.5'                                              --> Occurs 20951 Times In Training Data
# 	'15000.0'                                          --> Occurs 2577 Times In Training Data
# 	'nan'                                              --> Occurs 1428 Times In Training Data
# 	'1.493806'                                         --> Occurs 380 Times In Training Data
# 	'1.4939999580383'                                  --> Occurs 190 Times In Training Data
# 	'1.494'                                            --> Occurs 80 Times In Training Data
#
#
# Attribute Name: Modality (1 Different Values)
#
# 	'MR'                                               --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: NumberOfAverages (10 Different Values)
#
# 	'1.0'                                              --> Occurs 330885 Times In Training Data
# 	'2.0'                                              --> Occurs 10188 Times In Training Data
# 	'0.75'                                             --> Occurs 3162 Times In Training Data
# 	'0.5'                                              --> Occurs 2070 Times In Training Data
# 	'nan'                                              --> Occurs 1214 Times In Training Data
# 	'3.0'                                              --> Occurs 483 Times In Training Data
# 	'1.5'                                              --> Occurs 275 Times In Training Data
# 	'0.947368'                                         --> Occurs 220 Times In Training Data
# 	'0.705488'                                         --> Occurs 120 Times In Training Data
# 	'1.2'                                              --> Occurs 24 Times In Training Data
#
#
# Attribute Name: PatientID (585 Different Values)
#
# 	'00747'                                            --> Occurs 1372 Times In Training Data
# 	'00691'                                            --> Occurs 1350 Times In Training Data
# 	'00558'                                            --> Occurs 1312 Times In Training Data
# 	'00723'                                            --> Occurs 1254 Times In Training Data
# 	'00504'                                            --> Occurs 1240 Times In Training Data
# 	'00705'                                            --> Occurs 1224 Times In Training Data
# 	'00730'                                            --> Occurs 1195 Times In Training Data
# 	'00615'                                            --> Occurs 1190 Times In Training Data
# 	'00012'                                            --> Occurs 1183 Times In Training Data
# 	'00491'                                            --> Occurs 1167 Times In Training Data
# 	'00554'                                            --> Occurs 1148 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: PatientName (585 Different Values)
#
# 	'00747'                                            --> Occurs 1372 Times In Training Data
# 	'00691'                                            --> Occurs 1350 Times In Training Data
# 	'00558'                                            --> Occurs 1312 Times In Training Data
# 	'00723'                                            --> Occurs 1254 Times In Training Data
# 	'00504'                                            --> Occurs 1240 Times In Training Data
# 	'00705'                                            --> Occurs 1224 Times In Training Data
# 	'00730'                                            --> Occurs 1195 Times In Training Data
# 	'00615'                                            --> Occurs 1190 Times In Training Data
# 	'00012'                                            --> Occurs 1183 Times In Training Data
# 	'00491'                                            --> Occurs 1167 Times In Training Data
# 	'00554'                                            --> Occurs 1148 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: PatientPosition (1 Different Values)
#
# 	'HFS'                                              --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: PercentPhaseFieldOfView (30 Different Values)
#
# 	'100.0'                                            --> Occurs 105023 Times In Training Data
# 	'75.0'                                             --> Occurs 84283 Times In Training Data
# 	'90.0'                                             --> Occurs 55729 Times In Training Data
# 	'80.0'                                             --> Occurs 50959 Times In Training Data
# 	'85.0'                                             --> Occurs 25748 Times In Training Data
# 	'81.25'                                            --> Occurs 12628 Times In Training Data
# 	'70.0'                                             --> Occurs 3500 Times In Training Data
# 	'87.5'                                             --> Occurs 2711 Times In Training Data
# 	'90.625'                                           --> Occurs 1785 Times In Training Data
# 	'95.0'                                             --> Occurs 1568 Times In Training Data
# 	'nan'                                              --> Occurs 1402 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: PercentSampling (34 Different Values)
#
# 	'100.0'                                            --> Occurs 331785 Times In Training Data
# 	'75.0'                                             --> Occurs 4513 Times In Training Data
# 	'80.0'                                             --> Occurs 2882 Times In Training Data
# 	'nan'                                              --> Occurs 1616 Times In Training Data
# 	'53.125'                                           --> Occurs 1106 Times In Training Data
# 	'80.2030487060546'                                 --> Occurs 1041 Times In Training Data
# 	'70.0'                                             --> Occurs 810 Times In Training Data
# 	'98.0'                                             --> Occurs 796 Times In Training Data
# 	'95.0'                                             --> Occurs 560 Times In Training Data
# 	'56.25'                                            --> Occurs 548 Times In Training Data
# 	'55.0'                                             --> Occurs 441 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: PhotometricInterpretation (1 Different Values)
#
# 	'MONOCHROME2'                                      --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: PixelBandwidth (85 Different Values)
#
# 	'244.141'                                          --> Occurs 68062 Times In Training Data
# 	'150.0'                                            --> Occurs 64558 Times In Training Data
# 	'195.312'                                          --> Occurs 52900 Times In Training Data
# 	'278.984'                                          --> Occurs 21028 Times In Training Data
# 	'139.492'                                          --> Occurs 20192 Times In Training Data
# 	'390.625'                                          --> Occurs 18962 Times In Training Data
# 	'122.07'                                           --> Occurs 13047 Times In Training Data
# 	'193.0'                                            --> Occurs 10420 Times In Training Data
# 	'325.547'                                          --> Occurs 9995 Times In Training Data
# 	'287.0'                                            --> Occurs 9812 Times In Training Data
# 	'325.508'                                          --> Occurs 9756 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: PixelRepresentation (2 Different Values)
#
# 	'1'                                                --> Occurs 242708 Times In Training Data
# 	'0'                                                --> Occurs 105933 Times In Training Data
#
#
# Attribute Name: PixelSpacing (66 Different Values)
#
# 	'[0.5, 0.5]'                                       --> Occurs 163204 Times In Training Data
# 	'[0.9765625, 0.9765625]'                           --> Occurs 61175 Times In Training Data
# 	'[1, 1]'                                           --> Occurs 53430 Times In Training Data
# 	'[0.9375, 0.9375]'                                 --> Occurs 22166 Times In Training Data
# 	'[0.48828125, 0.48828125]'                         --> Occurs 7765 Times In Training Data
# 	'[0.468800008296967, 0.468800008296967]'           --> Occurs 5825 Times In Training Data
# 	'[1.01559996604919, 1.01559996604919]'             --> Occurs 5293 Times In Training Data
# 	'[0.507799983024597, 0.507799983024597]'           --> Occurs 3635 Times In Training Data
# 	'[1.015625, 1.015625]'                             --> Occurs 2100 Times In Training Data
# 	'[0.4296875, 0.4296875]'                           --> Occurs 1826 Times In Training Data
# 	'[0.976562023162842, 0.976562023162842]'           --> Occurs 1576 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: PositionReferenceIndicator (3 Different Values)
#
# 	''                                                 --> Occurs 346209 Times In Training Data
# 	'NA'                                               --> Occurs 1218 Times In Training Data
# 	'None'                                             --> Occurs 1214 Times In Training Data
#
#
# Attribute Name: ReconstructionDiameter (18 Different Values)
#
# 	'256.0'                                            --> Occurs 213710 Times In Training Data
# 	'nan'                                              --> Occurs 106055 Times In Training Data
# 	'240.0'                                            --> Occurs 9015 Times In Training Data
# 	'260.0'                                            --> Occurs 8928 Times In Training Data
# 	'200.0'                                            --> Occurs 2335 Times In Training Data
# 	'250.0'                                            --> Occurs 1454 Times In Training Data
# 	'230.0'                                            --> Occurs 1452 Times In Training Data
# 	'220.0'                                            --> Occurs 1308 Times In Training Data
# 	'276.0'                                            --> Occurs 1088 Times In Training Data
# 	'280.0'                                            --> Occurs 702 Times In Training Data
# 	'270.0'                                            --> Occurs 640 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: RescaleIntercept (1 Different Values)
#
# 	'0.0'                                              --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: RescaleSlope (1 Different Values)
#
# 	'1.0'                                              --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: RescaleType (1 Different Values)
#
# 	'US'                                               --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: Rows (14 Different Values)
#
# 	'512'                                              --> Occurs 191319 Times In Training Data
# 	'256'                                              --> Occurs 150866 Times In Training Data
# 	'320'                                              --> Occurs 2794 Times In Training Data
# 	'448'                                              --> Occurs 1328 Times In Training Data
# 	'440'                                              --> Occurs 560 Times In Training Data
# 	'640'                                              --> Occurs 494 Times In Training Data
# 	'480'                                              --> Occurs 358 Times In Training Data
# 	'244'                                              --> Occurs 320 Times In Training Data
# 	'384'                                              --> Occurs 310 Times In Training Data
# 	'672'                                              --> Occurs 84 Times In Training Data
# 	'240'                                              --> Occurs 75 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: SAR (1949 Different Values)
#
# 	'nan'                                              --> Occurs 1628 Times In Training Data
# 	'0.870041'                                         --> Occurs 1082 Times In Training Data
# 	'0.2608'                                           --> Occurs 856 Times In Training Data
# 	'0.889446'                                         --> Occurs 856 Times In Training Data
# 	'0.2477'                                           --> Occurs 816 Times In Training Data
# 	'0.2367'                                           --> Occurs 808 Times In Training Data
# 	'1.01235'                                          --> Occurs 784 Times In Training Data
# 	'0.2624'                                           --> Occurs 768 Times In Training Data
# 	'0.19438436627388'                                 --> Occurs 756 Times In Training Data
# 	'0.2907'                                           --> Occurs 752 Times In Training Data
# 	'0.362712'                                         --> Occurs 752 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: SamplesPerPixel (1 Different Values)
#
# 	'1'                                                --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: SeriesDescription (4 Different Values)
#
# 	'T2w'                                              --> Occurs 100000 Times In Training Data
# 	'T1wCE'                                            --> Occurs 96766 Times In Training Data
# 	'T1w'                                              --> Occurs 77627 Times In Training Data
# 	'FLAIR'                                            --> Occurs 74248 Times In Training Data
#
#
# Attribute Name: SeriesNumber (102 Different Values)
#
# 	'5'                                                --> Occurs 53229 Times In Training Data
# 	'4'                                                --> Occurs 32299 Times In Training Data
# 	'6'                                                --> Occurs 31912 Times In Training Data
# 	'2'                                                --> Occurs 28473 Times In Training Data
# 	'10'                                               --> Occurs 26122 Times In Training Data
# 	'3'                                                --> Occurs 19326 Times In Training Data
# 	'14'                                               --> Occurs 16922 Times In Training Data
# 	'7'                                                --> Occurs 15033 Times In Training Data
# 	'9'                                                --> Occurs 14733 Times In Training Data
# 	'12'                                               --> Occurs 13843 Times In Training Data
# 	'11'                                               --> Occurs 13660 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: SliceLocation (230287 Different Values)
#
# 	'nan'                                              --> Occurs 3524 Times In Training Data
# 	'12.816111564636'                                  --> Occurs 24 Times In Training Data
# 	'-8.1838884353638'                                 --> Occurs 24 Times In Training Data
# 	'9.8161115646362'                                  --> Occurs 24 Times In Training Data
# 	'15.816111564636'                                  --> Occurs 24 Times In Training Data
# 	'-11.183888435364'                                 --> Occurs 24 Times In Training Data
# 	'-14.183888435364'                                 --> Occurs 24 Times In Training Data
# 	'-23.065244674683'                                 --> Occurs 19 Times In Training Data
# 	'-29.065244674683'                                 --> Occurs 19 Times In Training Data
# 	'-17.065244674683'                                 --> Occurs 19 Times In Training Data
# 	'27.934755325317'                                  --> Occurs 19 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: SliceThickness (21 Different Values)
#
# 	'1.0'                                              --> Occurs 195028 Times In Training Data
# 	'1.2'                                              --> Occurs 71716 Times In Training Data
# 	'3.0'                                              --> Occurs 24737 Times In Training Data
# 	'2.0'                                              --> Occurs 19646 Times In Training Data
# 	'5.0'                                              --> Occurs 14711 Times In Training Data
# 	'1.5'                                              --> Occurs 7574 Times In Training Data
# 	'1.4'                                              --> Occurs 4272 Times In Training Data
# 	'1.1'                                              --> Occurs 3832 Times In Training Data
# 	'0.9'                                              --> Occurs 1558 Times In Training Data
# 	'4.0'                                              --> Occurs 1083 Times In Training Data
# 	'0.4688000083'                                     --> Occurs 1027 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: SpacingBetweenSlices (1 Different Values)
#
# 	'1.0'                                              --> Occurs 348641 Times In Training Data
#
#
# Attribute Name: SpecificCharacterSet (2 Different Values)
#
# 	'ISO_IR 100'                                       --> Occurs 347693 Times In Training Data
# 	'ISO_IR 192'                                       --> Occurs 948 Times In Training Data
#
#
# Attribute Name: TriggerWindow (2 Different Values)
#
# 	'0.0'                                              --> Occurs 242158 Times In Training Data
# 	'nan'                                              --> Occurs 106483 Times In Training Data
#
#
# Attribute Name: WindowCenter (25245 Different Values)
#
# 	'None'                                             --> Occurs 1218 Times In Training Data
# 	'0.0'                                              --> Occurs 788 Times In Training Data
# 	'452'                                              --> Occurs 650 Times In Training Data
# 	'503'                                              --> Occurs 628 Times In Training Data
# 	'1030'                                             --> Occurs 607 Times In Training Data
# 	'1216'                                             --> Occurs 600 Times In Training Data
# 	'1518'                                             --> Occurs 592 Times In Training Data
# 	'350'                                              --> Occurs 548 Times In Training Data
# 	'469'                                              --> Occurs 534 Times In Training Data
# 	'444'                                              --> Occurs 518 Times In Training Data
# 	'669'                                              --> Occurs 516 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------
#
#
# Attribute Name: WindowWidth (26925 Different Values)
#
# 	'None'                                             --> Occurs 1218 Times In Training Data
# 	'1'                                                --> Occurs 793 Times In Training Data
# 	'2084'                                             --> Occurs 574 Times In Training Data
# 	'2316'                                             --> Occurs 568 Times In Training Data
# 	'2898'                                             --> Occurs 561 Times In Training Data
# 	'32767'                                            --> Occurs 398 Times In Training Data
# 	'943'                                              --> Occurs 390 Times In Training Data
# 	'2234'                                             --> Occurs 377 Times In Training Data
# 	'1118'                                             --> Occurs 370 Times In Training Data
# 	'1398'                                             --> Occurs 363 Times In Training Data
# 	'950'                                              --> Occurs 356 Times In Training Data
#
# 	--------- TRUNCATED ------ ENDING EARLY ------ TRUNCATED ---------

# %% [markdown]
# <br>
#
# <a id="helper_functions"></a>
#
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;" id="3d_numpy">5&nbsp;&nbsp;LOAD 3D REPRESENTATIONS OF EXAMPLES</h1>
#
# I have gone ahead and created 3D numpy arrays containing the images interpolated to a fixed size (512,512,128) or (128,128,32). Please see this notebook for details on how this was completed.
#
# <br>
#
# **NOTE SOME IDS DO NOT POSSESS RESPECTIVE SCANS WITH NON-ZERO VALUES**
# * FLAIR --> ['00709.npz', '00109.npz']
# * T1w   --> ['00123.npz']
# * T1wCE --> []
# * T2w   --> ['00123.npz']

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">5.1  SETUP FILE PATHS</h2>
#
# ---

# %%
# train_ids = [f"{x:>05}.npz" for x in os.listdir("../input/rsna-miccai-brain-tumor-radiogenomic-classification/train")]

# print([x for x in train_ids if x not in os.listdir(FLAIR_NPY_DIR)])
# print([x for x in train_ids if x not in os.listdir(T1w_NPY_DIR)])
# print([x for x in train_ids if x not in os.listdir(T1wCE_NPY_DIR)])
# print([x for x in train_ids if x not in os.listdir(T2w_NPY_DIR)])

# total_sum = 0
# IDX = "00026"
# TYPE = "T2w"
# for i in range(1000):
#     try:
#         total_sum+=pydicom.read_file([os.path.join(f"/kaggle/input/rsna-miccai-brain-tumor-radiogenomic-classification/train/{IDX}/{TYPE}", x) for x in os.listdir(f"/kaggle/input/rsna-miccai-brain-tumor-radiogenomic-classification/train/{IDX}/{TYPE}")][i]).pixel_array.max()
#     except:
#         break
        
# print(total_sum)

# %%
TRAIN_NPY_DIR = "/kaggle/input/create-3d-npz-rsna-radiogenomic-classification/train"
# TRAIN_NPY_DIR = "/kaggle/input/rsna-radiogenomic-3dnumpy-512x512x128/train"
TEST_NPY_DIR = "/kaggle/input/create-3d-npz-rsna-radiogenomic-classification/test"

TRAIN_FLAIR_NPY_DIR = os.path.join(TRAIN_NPY_DIR, "FLAIR")
TRAIN_T1w_NPY_DIR = os.path.join(TRAIN_NPY_DIR, "T1w")
TRAIN_T1wCE_NPY_DIR = os.path.join(TRAIN_NPY_DIR, "T1wCE")
TRAIN_T2w_NPY_DIR = os.path.join(TRAIN_NPY_DIR, "T2w")

TEST_FLAIR_NPY_DIR = os.path.join(TEST_NPY_DIR, "FLAIR")
TEST_T1w_NPY_DIR = os.path.join(TEST_NPY_DIR, "T1w")
TEST_T1wCE_NPY_DIR = os.path.join(TEST_NPY_DIR, "T1wCE")
TEST_T2w_NPY_DIR = os.path.join(TEST_NPY_DIR, "T2w")


print("\n... FILE COUNTS ...\n")
print(f"\t--> The number of FLAIR numpy files is:  {len(os.listdir(TRAIN_FLAIR_NPY_DIR))}  ...")
print(f"\t--> The number of T1w   numpy files is:  {len(os.listdir(TRAIN_T1w_NPY_DIR))}  ...")
print(f"\t--> The number of T1wCE numpy files is:  {len(os.listdir(TRAIN_T1wCE_NPY_DIR))}  ...")
print(f"\t--> The number of T2w   numpy files is:  {len(os.listdir(TRAIN_T2w_NPY_DIR))}  ...\n")
# Out:
# ... FILE COUNTS ...
#
# 	--> The number of FLAIR numpy files is:  583  ...
# 	--> The number of T1w   numpy files is:  584  ...
# 	--> The number of T1wCE numpy files is:  585  ...
# 	--> The number of T2w   numpy files is:  584  ...

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">5.2  UPDATE THE TRAIN DATAFRAME</h2>
#
# ---

# %%
train_df["path_to_flair_npz"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_FLAIR_NPY_DIR, f"{x:>05}.npz"))
train_df["path_to_t1w_npz"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_T1w_NPY_DIR, f"{x:>05}.npz"))
train_df["path_to_t1wce_npz"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_T1wCE_NPY_DIR, f"{x:>05}.npz"))
train_df["path_to_t2w_npz"] = train_df.BraTS21ID.apply(lambda x: os.path.join(TRAIN_T2w_NPY_DIR, f"{x:>05}.npz"))

ss_df["path_to_flair_npz"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_FLAIR_NPY_DIR, f"{x:>05}.npz"))
ss_df["path_to_t1w_npz"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_T1w_NPY_DIR, f"{x:>05}.npz"))
ss_df["path_to_t1wce_npz"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_T1wCE_NPY_DIR, f"{x:>05}.npz"))
ss_df["path_to_t2w_npz"] = ss_df.BraTS21ID.apply(lambda x: os.path.join(TEST_T2w_NPY_DIR, f"{x:>05}.npz"))

display(train_df.head())
display(ss_df.head())
# Out:
#    BraTS21ID  MGMT_value                                  path_to_flair_dir  \
# 0          0           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1          2           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2          3           0  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3          5           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4          6           1  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    flair_image_count                                    path_to_t1w_dir  \
# 0                400  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                400  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1w_image_count                                  path_to_t1wce_dir  \
# 0               33  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1               31  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2               33  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3               28  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1wce_image_count                                    path_to_t2w_dir  \
# 0                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t2w_image_count                                  path_to_flair_npz  \
# 0              408  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1              384  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2              408  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3              424  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4              408  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
#
#                                      path_to_t1w_npz  \
# 0  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
#
#                                    path_to_t1wce_npz  \
# 0  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
#
#                                      path_to_t2w_npz
# 0  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
#    BraTS21ID  MGMT_value                                  path_to_flair_dir  \
# 0          1         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1         13         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2         15         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3         27         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4         37         0.5  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    flair_image_count                                    path_to_t1w_dir  \
# 0                208  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                204  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1w_image_count                                  path_to_t1wce_dir  \
# 0               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1               30  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4               32  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t1wce_image_count                                    path_to_t2w_dir  \
# 0                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 1                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 2                304  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 3                304  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
# 4                129  /kaggle/input/rsna-miccai-brain-tumor-radiogen...
#
#    t2w_image_count                                  path_to_flair_npz  \
# 0              129  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1              408  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2              408  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3              129  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4              424  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
#
#                                      path_to_t1w_npz  \
# 0  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
#
#                                    path_to_t1wce_npz  \
# 0  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
#
#                                      path_to_t2w_npz
# 0  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 1  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 2  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 3  /kaggle/input/create-3d-npz-rsna-radiogenomic-...
# 4  /kaggle/input/create-3d-npz-rsna-radiogenomic-...

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">5.3  VISUALIZE A RANDOM SCAN</h2>
#
# ---

# %%
RANDOM_IMG_IDX = int(random.random()*len(train_df))
print(f"\n... Visualize Single Flair Scan From Disk - IDX={RANDOM_IMG_IDX} ...\n")
display(create_animation(load_npz(train_df.path_to_flair_npz[RANDOM_IMG_IDX])))

RANDOM_IMG_IDX = int(random.random()*len(train_df))
print(f"\n... Visualize Set of mpMRI Scans From Disk - IDX={RANDOM_IMG_IDX} ...\n")
display(create_4scan_animation(
    load_npz(train_df.path_to_flair_npz[RANDOM_IMG_IDX]),
    load_npz(train_df.path_to_t1w_npz[RANDOM_IMG_IDX]),
    load_npz(train_df.path_to_t1wce_npz[RANDOM_IMG_IDX]),
    load_npz(train_df.path_to_t2w_npz[RANDOM_IMG_IDX]),
))

print(train_df.path_to_flair_npz[RANDOM_IMG_IDX])
print(train_df.path_to_t1w_npz[RANDOM_IMG_IDX])
print(train_df.path_to_t1wce_npz[RANDOM_IMG_IDX])
print(train_df.path_to_t2w_npz[RANDOM_IMG_IDX])
# Out:
# ... Visualize Single Flair Scan From Disk - IDX=189 ...
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf62d18532b0941aa95f1853fb12e11cd">
#   <div class="anim-controls">
#     <input id="_anim_sliderf62d18532b0941aa95f1853fb12e11cd" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf62d18532b0941aa95f1853fb12e11cd.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animf62d18532b0941aa95f1853fb12e11cd.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animf62d18532b0941aa95f1853fb12e11cd.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animf62d18532b0941aa95f1853fb12e11cd.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animf62d18532b0941aa95f1853fb12e11cd.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animf62d18532b0941aa95f1853fb12e11cd.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animf62d18532b0941aa95f1853fb12e11cd.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animf62d18532b0941aa95f1853fb12e11cd.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animf62d18532b0941aa95f1853fb12e11cd.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animf62d18532b0941aa95f1853fb12e11cd.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectf62d18532b0941aa95f1853fb12e11cd"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f62d18532b0941aa95f1853fb12e11cd"
#              >
#       <label for="_anim_radio1_f62d18532b0941aa95f1853fb12e11cd">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f62d18532b0941aa95f1853fb12e11cd"
#              checked>
#       <label for="_anim_radio2_f62d18532b0941aa95f1853fb12e11cd">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f62d18532b0941aa95f1853fb12e11cd"
#              >
#       <label for="_anim_radio3_f62d18532b0941aa95f1853fb12e11cd">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf62d18532b0941aa95f1853fb12e11cd";
#     var slider_id = "_anim_sliderf62d18532b0941aa95f1853fb12e11cd";
#     var loop_select_id = "_anim_loop_selectf62d18532b0941aa95f1853fb12e11cd";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/Z1A+gAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA
# ... Visualize Set of mpMRI Scans From Disk - IDX=88 ...
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9d486a858d164c148701811c2dc43def">
#   <div class="anim-controls">
#     <input id="_anim_slider9d486a858d164c148701811c2dc43def" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9d486a858d164c148701811c2dc43def.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim9d486a858d164c148701811c2dc43def.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim9d486a858d164c148701811c2dc43def.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim9d486a858d164c148701811c2dc43def.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim9d486a858d164c148701811c2dc43def.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim9d486a858d164c148701811c2dc43def.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim9d486a858d164c148701811c2dc43def.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim9d486a858d164c148701811c2dc43def.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim9d486a858d164c148701811c2dc43def.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim9d486a858d164c148701811c2dc43def.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select9d486a858d164c148701811c2dc43def"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9d486a858d164c148701811c2dc43def"
#              >
#       <label for="_anim_radio1_9d486a858d164c148701811c2dc43def">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9d486a858d164c148701811c2dc43def"
#              checked>
#       <label for="_anim_radio2_9d486a858d164c148701811c2dc43def">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9d486a858d164c148701811c2dc43def"
#              >
#       <label for="_anim_radio3_9d486a858d164c148701811c2dc43def">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9d486a858d164c148701811c2dc43def";
#     var slider_id = "_anim_slider9d486a858d164c148701811c2dc43def";
#     var loop_select_id = "_anim_loop_select9d486a858d164c148701811c2dc43def";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/Z1A+gAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA
# /kaggle/input/create-3d-npz-rsna-radiogenomic-classification/train/FLAIR/00136.npz
# /kaggle/input/create-3d-npz-rsna-radiogenomic-classification/train/T1w/00136.npz
# /kaggle/input/create-3d-npz-rsna-radiogenomic-classification/train/T1wCE/00136.npz
# /kaggle/input/create-3d-npz-rsna-radiogenomic-classification/train/T2w/00136.npz

# %%
# def get_3d_effnet(dropout=0.5):
#     """Build a 3D convolutional neural network model."""

#     inputs = tf.keras.layers.Input(shape=INPUT_SHAPE)
#     pp_inputs = tf.keras.applications.efficientnet.preprocess_input(inputs)
#     x = efn.EfficientNetB0(input_shape=INPUT_SHAPE, pooling="avg")(pp_inputs)
    
#     x = tf.keras.layers.Dropout(dropout)(x)
#     x = tf.keras.layers.Dense(units=256, activation="relu")(x)

#     x = tf.keras.layers.Dropout(dropout/1.25)(x)
#     outputs = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

#     # Define the model.
#     model = tf.keras.Model(inputs, outputs, name="3d_mpmri_cnn")
#     return model

# model = get_3d_effnet()
# print(model.predict(tf.repeat(load_npz(train_df.path_to_flair_npz[RANDOM_IMG_IDX]).reshape(1, *INPUT_SHAPE[:-1], 1), axis=-1, repeats=3)))

# %% [markdown]
# <br>
#
# <a id="background_information"></a>
#
# <h1 style="font-family: Verdana; font-size: 24px; font-style: normal; font-weight: bold; text-decoration: none; text-transform: none; letter-spacing: 3px; color: #CD0001; background-color: #ffffff;" id="modelling">6&nbsp;&nbsp;MODELLING</h1>

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">6.1 CREATE THE MODELS</h2>
#
# ---
#
# <br>
#
# One for each type of scan
#
# <br>

# %%
INPUT_SHAPE = (128,128,32,1)
BATCH_SIZE = 8

def get_3d_model(width=128, height=128, depth=32, dropout=0.3):
    """Build a 3D convolutional neural network model."""

    inputs = tf.keras.layers.Input(shape=(width, height, depth, 1))

    # print(x.shape)
    # x1 = tf.keras.layers.Conv3D(filters=64, kernel_size=1, activation=None, padding="same")(inputs)
    # x1 = tf.keras.layers.MaxPool3D(pool_size=2)(x1)
    # x1 = tf.keras.layers.BatchNormalization()(x1)
    
    x = tf.keras.layers.Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = tf.keras.layers.MaxPool3D(pool_size=2)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    # x3 = tf.keras.layers.Conv3D(filters=64, kernel_size=5, activation=None, padding="same")(inputs)
    # x3 = tf.keras.layers.MaxPool3D(pool_size=2)(x3)
    # x3 = tf.keras.layers.BatchNormalization()(x3)
    # x = tf.keras.layers.Add()([x1,x2,x3])
    # x = tf.keras.layers.Activation("relu")(x)
    
    x = tf.keras.layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = tf.keras.layers.MaxPool3D(pool_size=2)(x)
    x = tf.keras.layers.BatchNormalization()(x)

    # print(x.shape)
    x = tf.keras.layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    # x = tf.keras.layers.MaxPool3D(pool_size=2)(x)
    x = tf.keras.layers.BatchNormalization()(x)

    # print(x.shape)
    x = tf.keras.layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    # x = tf.keras.layers.MaxPool3D(pool_size=2)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout/2)(x)
    
    # print(x.shape)
    x = tf.keras.layers.GlobalAveragePooling3D()(x)
    x = tf.keras.layers.Dense(units=128, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # print(x.shape)
    outputs = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = tf.keras.Model(inputs, outputs, name="3d_mpmri_cnn")
    return model


# Build model.
DROPOUT = 0.666
flair_model = get_3d_model(width=INPUT_SHAPE[0], height=INPUT_SHAPE[1], depth=INPUT_SHAPE[2], dropout=DROPOUT)
t1w_model = get_3d_model(width=INPUT_SHAPE[0], height=INPUT_SHAPE[1], depth=INPUT_SHAPE[2], dropout=DROPOUT)
t1wce_model = get_3d_model(width=INPUT_SHAPE[0], height=INPUT_SHAPE[1], depth=INPUT_SHAPE[2], dropout=DROPOUT)
t2w_model = get_3d_model(width=INPUT_SHAPE[0], height=INPUT_SHAPE[1], depth=INPUT_SHAPE[2], dropout=DROPOUT)
models = {"flair":flair_model, "t1w":t1w_model, "t1wce":t1wce_model, "t2w":t2w_model}

print("\n... EXAMPLE PREDICTION ...\n")
print(flair_model.predict(load_npz(train_df.path_to_flair_npz[RANDOM_IMG_IDX]).reshape(1, *INPUT_SHAPE)))

print("\n\n... MODEL SUMMARY ...\n")
flair_model.summary()
# Out:
# ... EXAMPLE PREDICTION ...
#
# [[0.30933473]]
#
#
# ... MODEL SUMMARY ...
#
# Model: "3d_mpmri_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 32, 1)] 0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 126, 126, 30, 64)  1792
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 63, 63, 15, 64)    0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 63, 63, 15, 64)    256
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 61, 61, 13, 64)    110656
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 30, 30, 6, 64)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 6, 64)     256
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 28, 28, 4, 128)    221312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 4, 128)    512
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 26, 26, 2, 256)    884992
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 26, 26, 2, 256)    1024
# _________________________________________________________________
# dropout (Dropout)            (None, 26, 26, 2, 256)    0
# _________________________________________________________________
# global_average_pooling3d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,253,825
# Trainable params: 1,252,801
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">6.2  CREATE THE DATASETS</h2>
#
# ---

# %%
# This is dataframe wrangling
USE_COL = "all" # one of [`all`, `path_to_t1w_npz`, `path_to_t1wce_npz`, `path_to_flair_npz`, `path_to_t2w_npz`]
if USE_COL is "all":
    USE_COLS = ["path_to_t1w_npz", "path_to_t1wce_npz", "path_to_flair_npz", "path_to_t2w_npz"]
else:
    USE_COLS = [USE_COL,]

# Initialize dictionaries
dataset_storage = {}

for use_col in USE_COLS:
    col_identifier = use_col.split("_")[2]
    dataset_storage[col_identifier] = {}
    
    dataset_storage[col_identifier]["train_ds_df"] = train_df[train_df[use_col].apply(lambda x: True if os.path.isfile(x) else False)][["MGMT_value", use_col]]
    dataset_storage[col_identifier]["train_lbl_list"] = dataset_storage[col_identifier]["train_ds_df"].MGMT_value.to_list()
    dataset_storage[col_identifier]["train_npz_file_list"] = dataset_storage[col_identifier]["train_ds_df"][use_col].to_list()

    # fix this.......
    dataset_storage[col_identifier]["test_ds_df"] = ss_df[ss_df[use_col].apply(lambda x: True if os.path.isfile(x) else False)][["BraTS21ID", use_col]]
    dataset_storage[col_identifier]["test_id_list"] = dataset_storage[col_identifier]["test_ds_df"].BraTS21ID.to_list()
    dataset_storage[col_identifier]["test_npz_file_list"] = dataset_storage[col_identifier]["test_ds_df"][use_col].to_list()

    # This is for splitting
    dataset_storage[col_identifier]["N_EX"] = len(dataset_storage[col_identifier]["train_lbl_list"])
    dataset_storage[col_identifier]["VAL_FRAC"] = 0.1
    dataset_storage[col_identifier]["N_TRAIN"] = int(dataset_storage[col_identifier]["N_EX"]*(1-dataset_storage[col_identifier]["VAL_FRAC"]))
    dataset_storage[col_identifier]["N_VAL"] = dataset_storage[col_identifier]["N_EX"]-dataset_storage[col_identifier]["N_TRAIN"]
    dataset_storage[col_identifier]["RANDOM_INDICES"] = random.sample(range(dataset_storage[col_identifier]["N_EX"]), dataset_storage[col_identifier]["N_EX"])
    dataset_storage[col_identifier]["TRAIN_INDICES"] = dataset_storage[col_identifier]["RANDOM_INDICES"][:dataset_storage[col_identifier]["N_TRAIN"]]
    dataset_storage[col_identifier]["VAL_INDICES"] = dataset_storage[col_identifier]["RANDOM_INDICES"][dataset_storage[col_identifier]["N_TRAIN"]:]

    # TF Data Integration
    dataset_storage[col_identifier]["lbl_train_ds"] = tf.data.Dataset.from_tensor_slices(np.array(dataset_storage[col_identifier]["train_lbl_list"])[dataset_storage[col_identifier]["TRAIN_INDICES"]])
    dataset_storage[col_identifier]["npz_file_train_ds"] = tf.data.Dataset.from_tensor_slices(np.array(dataset_storage[col_identifier]["train_npz_file_list"])[dataset_storage[col_identifier]["TRAIN_INDICES"]])
    dataset_storage[col_identifier]["raw_train_ds"] = tf.data.Dataset.zip((dataset_storage[col_identifier]["npz_file_train_ds"], dataset_storage[col_identifier]["lbl_train_ds"]))

    dataset_storage[col_identifier]["lbl_val_ds"] = tf.data.Dataset.from_tensor_slices(np.array(dataset_storage[col_identifier]["train_lbl_list"])[dataset_storage[col_identifier]["VAL_INDICES"]])
    dataset_storage[col_identifier]["npz_file_val_ds"] = tf.data.Dataset.from_tensor_slices(np.array(dataset_storage[col_identifier]["train_npz_file_list"])[dataset_storage[col_identifier]["VAL_INDICES"]])
    dataset_storage[col_identifier]["raw_val_ds"] = tf.data.Dataset.zip((dataset_storage[col_identifier]["npz_file_val_ds"], dataset_storage[col_identifier]["lbl_val_ds"]))

    dataset_storage[col_identifier]["id_test_ds"] = tf.data.Dataset.from_tensor_slices(dataset_storage[col_identifier]["test_id_list"])
    dataset_storage[col_identifier]["npz_file_test_ds"] = tf.data.Dataset.from_tensor_slices(dataset_storage[col_identifier]["test_npz_file_list"])
    dataset_storage[col_identifier]["raw_test_ds"] = tf.data.Dataset.zip((dataset_storage[col_identifier]["npz_file_test_ds"], dataset_storage[col_identifier]["id_test_ds"]))

    if INPUT_SHAPE[-1]==3:
        dataset_storage[col_identifier]["train_ds"] = dataset_storage[col_identifier]["raw_train_ds"].map(lambda x,y: (tf.repeat(tf.reshape(tf.py_function(
            load_npz, [x, True], (tf.uint8,)
        ), (*INPUT_SHAPE[:-1], 1))/255, axis=-1, repeats=3), tf.cast(y, tf.uint8)), num_parallel_calls=tf.data.AUTOTUNE)
        dataset_storage[col_identifier]["train_ds"] = dataset_storage[col_identifier]["train_ds"].shuffle(BATCH_SIZE*5).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

        dataset_storage[col_identifier]["val_ds"] = dataset_storage[col_identifier]["raw_val_ds"].map(lambda x,y: (tf.repeat(tf.reshape(tf.py_function(
            load_npz, [x, True], (tf.uint8,)
        ), (*INPUT_SHAPE[:-1], 1))/255, axis=-1, repeats=3), tf.cast(y, tf.uint8)), num_parallel_calls=tf.data.AUTOTUNE)
        dataset_storage[col_identifier]["val_ds"] = dataset_storage[col_identifier]["val_ds"].batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

        dataset_storage[col_identifier]["test_ds"] = dataset_storage[col_identifier]["raw_test_ds"].map(lambda x,y: (tf.repeat(tf.reshape(tf.py_function(
            load_npz, [x, True], (tf.uint8,)
        ), (*INPUT_SHAPE[:-1], 1))/255, axis=-1, repeats=3), tf.cast(y, tf.int32)), num_parallel_calls=tf.data.AUTOTUNE)
        dataset_storage[col_identifier]["test_ds"] = dataset_storage[col_identifier]["test_ds"].batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    else:
        dataset_storage[col_identifier]["train_ds"] = dataset_storage[col_identifier]["raw_train_ds"].map(lambda x,y: (tf.reshape(tf.py_function(
            load_npz, [x, True], (tf.uint8,)
        ), INPUT_SHAPE)/255, tf.cast(y, tf.uint8)), num_parallel_calls=tf.data.AUTOTUNE)
        dataset_storage[col_identifier]["train_ds"] = dataset_storage[col_identifier]["train_ds"].shuffle(BATCH_SIZE*5).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

        dataset_storage[col_identifier]["val_ds"] = dataset_storage[col_identifier]["raw_val_ds"].map(lambda x,y: (tf.reshape(tf.py_function(
            load_npz, [x, True], (tf.uint8,)
        ), INPUT_SHAPE)/255, tf.cast(y, tf.uint8)), num_parallel_calls=tf.data.AUTOTUNE)
        dataset_storage[col_identifier]["val_ds"] = dataset_storage[col_identifier]["val_ds"].batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

        dataset_storage[col_identifier]["test_ds"] = dataset_storage[col_identifier]["raw_test_ds"].map(lambda x,y: (tf.reshape(tf.py_function(
            load_npz, [x, True], (tf.uint8,)
        ), INPUT_SHAPE)/255, tf.cast(y, tf.int32)), num_parallel_calls=tf.data.AUTOTUNE)
        dataset_storage[col_identifier]["test_ds"] = dataset_storage[col_identifier]["test_ds"].batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

for k, v in dataset_storage.items():
    print(f"\n\n... SCAN TYPE: {k.upper()}")
    print("\t-->", v["train_ds"])
    print("\t-->", v["val_ds"])
    print("\t-->", v["test_ds"])
print("\n")
# Out:
# ... SCAN TYPE: T1W
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.int32)>
#
#
# ... SCAN TYPE: T1WCE
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.int32)>
#
#
# ... SCAN TYPE: FLAIR
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.int32)>
#
#
# ... SCAN TYPE: T2W
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.uint8)>
# 	--> <PrefetchDataset shapes: ((None, 128, 128, 32, 1), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">6.3  VISUALIZE A FEW EXAMPLES</h2>
#
# ---

# %%
def plot_batch(dataset):
    r_idx = int(random.random()*BATCH_SIZE)
    
    img, lbl = next(iter(dataset))
    
    img = tf.squeeze(img[r_idx])
    lbl = lbl[r_idx]
    
    plt.figure(figsize=(20,10.5), )
    plt.suptitle(f"LABEL = {label_map_int_2_str[lbl.numpy()]} ({lbl.numpy()})", fontsize=20, fontweight="bold")
    for i in range(img.shape[-1]):
        plt.subplot(4,8,i+1)
        plt.imshow(img[..., i], cmap="gray")
        plt.axis(False)
    
    plt.tight_layout(h_pad=0.025, w_pad=0.025)
    # plt.subplots_adjust(wspace=0.001, hspace=0.001)
    plt.show()
    

for k, v in dataset_storage.items():
    print("\n\n\n\n\n\n"+"-"*35)
    print("-"*35)
    print(f"\t SCAN TYPE: {k.upper()}")
    print("-"*35)
    print("-"*35,"\n\n")
    
    print(f"\n\n... DEMO TRAIN {k.upper()} EXAMPLE ...\n\n")
    plot_batch(v["train_ds"])
    
    print(f"\n\n... DEMO VALIDATION {k.upper()} EXAMPLE ...\n\n")
    plot_batch(v["val_ds"])

print("\n")
# Out:
# -----------------------------------
# -----------------------------------
# 	 SCAN TYPE: T1W
# -----------------------------------
# -----------------------------------
#
#
#
#
# ... DEMO TRAIN T1W EXAMPLE ...
# ... DEMO VALIDATION T1W EXAMPLE ...
# -----------------------------------
# -----------------------------------
# 	 SCAN TYPE: T1WCE
# -----------------------------------
# -----------------------------------
#
#
#
#
# ... DEMO TRAIN T1WCE EXAMPLE ...
# ... DEMO VALIDATION T1WCE EXAMPLE ...
# -----------------------------------
# -----------------------------------
# 	 SCAN TYPE: FLAIR
# -----------------------------------
# -----------------------------------
#
#
#
#
# ... DEMO TRAIN FLAIR EXAMPLE ...
# ... DEMO VALIDATION FLAIR EXAMPLE ...
# -----------------------------------
# -----------------------------------
# 	 SCAN TYPE: T2W
# -----------------------------------
# -----------------------------------
#
#
#
#
# ... DEMO TRAIN T2W EXAMPLE ...
# ... DEMO VALIDATION T2W EXAMPLE ...

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">6.4  LEARNING RATE FUNCTION/PLOT</h2>
#
# ---

# %%
# Learning Rate
MAX_STEPS = 20000
INIT_LR = 0.00015
DECAY_RATE = 0.98
DECAY_STEPS = int((len(train_df)/BATCH_SIZE)*5) # 5 epochs = 1 decay
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    INIT_LR, decay_steps=DECAY_STEPS, decay_rate=DECAY_RATE, staircase=True
)

# Plot Learning Rate
plt.figure(figsize=(10,10))
plt.plot(range(0, MAX_STEPS, int(len(train_df)/BATCH_SIZE)), [lr_schedule(i) for i in range(0, MAX_STEPS, int(len(train_df)/BATCH_SIZE))], linewidth=3)
plt.vlines(range(int(len(train_df)/BATCH_SIZE*5), MAX_STEPS, int(len(train_df)/BATCH_SIZE*5)), ymin=0, ymax=INIT_LR, linestyles="dotted", colors='gray')
plt.vlines(range(int(len(train_df)/BATCH_SIZE*50), MAX_STEPS, int(len(train_df)/BATCH_SIZE*50)), ymin=0, ymax=INIT_LR, colors='r')
plt.title("Learning Rate\nDotted Lines At Every 5 Epochs (~350 steps)\nSolid Red Lines At Every 50 Epochs", fontweight="bold")
plt.show()

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">6.5  TRAINING LOOP</h2>
#
# ---

# %%
# Compile model
N_EPOCHS=250
PATIENCE=50

histories = {}
for model_style, model in models.items():
    print("\n\n\n\n\n\n\n\n")
    print("-"*80)
    print("-"*20+"\t"+f"{model_style.upper()} TRAINING LOOP"+"\t"+"-"*20)
    print("-"*80)
    print("\n\n\n")
    
    # Get datasets
    train_ds = dataset_storage[model_style]["train_ds"]
    val_ds = dataset_storage[model_style]["val_ds"]
    
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        INIT_LR, decay_steps=DECAY_STEPS, decay_rate=DECAY_RATE, staircase=True
    )

    model.compile(
        loss="binary_crossentropy",
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        metrics=["acc", tf.keras.metrics.AUC(name="auc")],
    )

    # Define callbacks.
    CKPT_DIR = os.path.join("/kaggle/working/model_files", model_style)
    if not os.path.isdir(CKPT_DIR): 
        os.makedirs(CKPT_DIR, exist_ok=True)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        os.path.join(CKPT_DIR, "epoch_{epoch:02d}--val_loss_{val_loss:.2f}--val_auc_{val_auc:.2f}"), 
        save_best_only=True, monitor="val_auc", mode="max",
    )
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=PATIENCE, restore_best_weights=True, mode="max")
    
    # Train the model, doing validation at the end of each epoch
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=N_EPOCHS,
        callbacks=[checkpoint_cb, early_stopping_cb],
    )
    histories[model_style] = history
# Out:
# --------------------------------------------------------------------------------
# --------------------	FLAIR TRAINING LOOP	--------------------
# --------------------------------------------------------------------------------
#
#
#
#
# Epoch 1/250
# 66/66 [==============================] - 18s 230ms/step - loss: 0.7257 - acc: 0.5430 - auc: 0.5302 - val_loss: 0.6882 - val_acc: 0.5763 - val_auc: 0.4994
# Epoch 2/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.7285 - acc: 0.4632 - auc: 0.4942 - val_loss: 0.7644 - val_acc: 0.5763 - val_auc: 0.4582
# Epoch 3/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.7076 - acc: 0.5127 - auc: 0.5528 - val_loss: 0.8328 - val_acc: 0.5763 - val_auc: 0.5453
# Epoch 4/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.7084 - acc: 0.5498 - auc: 0.5436 - val_loss: 0.8090 - val_acc: 0.5763 - val_auc: 0.5600
# Epoch 5/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.7008 - acc: 0.5440 - auc: 0.5552 - val_loss: 0.8911 - val_acc: 0.5763 - val_auc: 0.5106
# Epoch 6/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.6892 - acc: 0.5554 - auc: 0.5905 - val_loss: 0.6785 - val_acc: 0.5254 - val_auc: 0.5853
# Epoch 7/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0.6823 - acc: 0.5760 - auc: 0.6037 - val_loss: 0.6796 - val_acc: 0.5763 - val_auc: 0.5859
# Epoch 8/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.6781 - acc: 0.5920 - auc: 0.6004 - val_loss: 0.6760 - val_acc: 0.5763 - val_auc: 0.6288
# Epoch 9/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.6751 - acc: 0.6025 - auc: 0.6186 - val_loss: 0.6521 - val_acc: 0.6271 - val_auc: 0.6671
# Epoch 10/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.6717 - acc: 0.5895 - auc: 0.6211 - val_loss: 0.6456 - val_acc: 0.5763 - val_auc: 0.6624
# Epoch 11/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0.6622 - acc: 0.5890 - auc: 0.6372 - val_loss: 0.6981 - val_acc: 0.5763 - val_auc: 0.6053
# Epoch 12/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.6546 - acc: 0.5989 - auc: 0.6596 - val_loss: 0.6901 - val_acc: 0.4915 - val_auc: 0.5065
# Epoch 13/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0
250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.1020 - acc: 0.9624 - auc: 0.9965 - val_loss: 1.2297 - val_acc: 0.6780 - val_auc: 0.6047
# Epoch 58/250
# 66/66 [==============================] - 14s 206ms/step - loss: 0.1070 - acc: 0.9741 - auc: 0.9914 - val_loss: 1.7901 - val_acc: 0.5763 - val_auc: 0.5988
# Epoch 59/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.1698 - acc: 0.9419 - auc: 0.9823 - val_loss: 1.3864 - val_acc: 0.5424 - val_auc: 0.5741
# Epoch 60/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.1442 - acc: 0.9296 - auc: 0.9888 - val_loss: 1.0849 - val_acc: 0.6271 - val_auc: 0.6635
# Epoch 61/250
# 66/66 [==============================] - 14s 205ms/step - loss: 0.1552 - acc: 0.9448 - auc: 0.9840 - val_loss: 1.6356 - val_acc: 0.4407 - val_auc: 0.5959
# Epoch 62/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.1116 - acc: 0.9603 - auc: 0.9953 - val_loss: 1.7785 - val_acc: 0.4407 - val_auc: 0.6059
# Epoch 63/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.1077 - acc: 0.9633 - auc: 0.9937 - val_loss: 1.1889 - val_acc: 0.5763 - val_auc: 0.6071
# Epoch 64/250
# 66/66 [==============================] - 14s 202ms/step - loss: 0.1081 - acc: 0.9613 - auc: 0.9927 - val_loss: 1.2519 - val_acc: 0.5932 - val_auc: 0.6171
# Epoch 65/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.0719 - acc: 0.9720 - auc: 0.9974 - val_loss: 2.3170 - val_acc: 0.6102 - val_auc: 0.6082
# Epoch 66/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.1594 - acc: 0.9358 - auc: 0.9867 - val_loss: 2.2661 - val_acc: 0.4746 - val_auc: 0.5400
# Epoch 67/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.0760 - acc: 0.9775 - auc: 0.9967 - val_loss: 1.1664 - val_acc: 0.6102 - val_auc: 0.6812
# Epoch 68/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.1481 - acc: 0.9468 - auc: 0.9865 - val_loss: 1.0304 - val_acc: 0.6780 - val_auc: 0.7200
#
#
#
#
#
#
#
#
#
# --------------------------------------------------------------------------------
# --------------------	T1W TRAINING LOOP	--------------------
# --------------------------------------------------------------------------------
#
#
#
#
# Epoch 1/250
# 66/66 [==============================] - 16s 218ms/step - loss: 0.7223 - acc: 0.5205 - auc: 0.5026 - val_loss: 0.7080 - val_acc: 0.4407 - val_auc: 0.5927
# Epoch 2/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.7223 - acc: 0.5068 - auc: 0.5000 - val_loss: 0.6822 - val_acc: 0.5593 - val_auc: 0.6026
# Epoch 3/250
# 66/66 [==============================] - 14s 202ms/step - loss: 0.7256 - acc: 0.5357 - auc: 0.5188 - val_loss: 0.6727 - val_acc: 0.5932 - val_auc: 0.6119
# Epoch 4/250
# 66/66 [==============================] - 14s 205ms/step - loss: 0.7179 - acc: 0.4948 - auc: 0.4866 - val_loss: 0.7587 - val_acc: 0.4407 - val_auc: 0.5728
# Epoch 5/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.7038 - acc: 0.5200 - auc: 0.5394 - val_loss: 0.6826 - val_acc: 0.5424 - val_auc: 0.5338
# Epoch 6/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.6946 - acc: 0.5639 - auc: 0.5600 - val_loss: 0.6846 - val_acc: 0.5593 - val_auc: 0.5501
# Epoch 7/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.6743 - acc: 0.5650 - auc: 0.6010 - val_loss: 0.6772 - val_acc: 0.5763 - val_auc: 0.5886
# Epoch 8/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0
250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.1717 - acc: 0.9549 - auc: 0.9807 - val_loss: 2.8349 - val_acc: 0.5932 - val_auc: 0.5379
# Epoch 71/250
# 66/66 [==============================] - 14s 207ms/step - loss: 0.1166 - acc: 0.9578 - auc: 0.9920 - val_loss: 1.7086 - val_acc: 0.5085 - val_auc: 0.5408
# Epoch 72/250
# 66/66 [==============================] - 14s 204ms/step - loss: 0.1093 - acc: 0.9522 - auc: 0.9933 - val_loss: 3.6358 - val_acc: 0.5593 - val_auc: 0.5326
# Epoch 73/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.1157 - acc: 0.9592 - auc: 0.9916 - val_loss: 1.7443 - val_acc: 0.6271 - val_auc: 0.6055
# Epoch 74/250
# 66/66 [==============================] - 14s 206ms/step - loss: 0.0867 - acc: 0.9788 - auc: 0.9961 - val_loss: 3.4603 - val_acc: 0.6102 - val_auc: 0.5332
# Epoch 75/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.1018 - acc: 0.9741 - auc: 0.9892 - val_loss: 2.1482 - val_acc: 0.5593 - val_auc: 0.6422
# Epoch 76/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.0917 - acc: 0.9779 - auc: 0.9935 - val_loss: 1.9707 - val_acc: 0.5763 - val_auc: 0.6061
# Epoch 77/250
# 66/66 [==============================] - 14s 205ms/step - loss: 0.0630 - acc: 0.9850 - auc: 0.9983 - val_loss: 2.0377 - val_acc: 0.6271 - val_auc: 0.5629
# Epoch 78/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.0794 - acc: 0.9811 - auc: 0.9927 - val_loss: 1.5921 - val_acc: 0.5763 - val_auc: 0.6166
# Epoch 79/250
# 66/66 [==============================] - 14s 210ms/step - loss: 0.0330 - acc: 0.9933 - auc: 0.9993 - val_loss: 2.1503 - val_acc: 0.5085 - val_auc: 0.5385
# Epoch 80/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.0750 - acc: 0.9718 - auc: 0.9969 - val_loss: 1.6633 - val_acc: 0.5932 - val_auc: 0.6568
# Epoch 81/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0.0712 - acc: 0.9739 - auc: 0.9972 - val_loss: 2.0854 - val_acc: 0.5424 - val_auc: 0.5536
# Epoch 82/250
# 66/66 [==============================] - 14s 208ms/step - loss: 0.0784 - acc: 0.9714 - auc: 0.9955 - val_loss: 2.6245 - val_acc: 0.5763 - val_auc: 0.6457
# Epoch 83/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.1357 - acc: 0.9557 - auc: 0.9858 - val_loss: 2.3288 - val_acc: 0.4915 - val_auc: 0.5967
# Epoch 84/250
# 66/66 [==============================] - 14s 207ms/step - loss: 0.0493 - acc: 0.9858 - auc: 0.9977 - val_loss: 1.7163 - val_acc: 0.5763 - val_auc: 0.6101
# Epoch 85/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.0663 - acc: 0.9830 - auc: 0.9968 - val_loss: 1.4591 - val_acc: 0.6271 - val_auc: 0.6294
#
#
#
#
#
#
#
#
#
# --------------------------------------------------------------------------------
# --------------------	T1WCE TRAINING LOOP	--------------------
# --------------------------------------------------------------------------------
#
#
#
#
# Epoch 1/250
# 66/66 [==============================] - 16s 224ms/step - loss: 0.7276 - acc: 0.4943 - auc: 0.5000 - val_loss: 0.6890 - val_acc: 0.6271 - val_auc: 0.5799
# Epoch 2/250
# 66/66 [==============================] - 14s 205ms/step - loss: 0.7130 - acc: 0.5449 - auc: 0.5356 - val_loss: 0.7458 - val_acc: 0.3729 - val_auc: 0.5258
# Epoch 3/250
# 66/66 [==============================] - 14s 202ms/step - loss: 0
250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.1225 - acc: 0.9445 - auc: 0.9924 - val_loss: 1.8798 - val_acc: 0.5085 - val_auc: 0.4681
# Epoch 60/250
# 66/66 [==============================] - 14s 215ms/step - loss: 0.0803 - acc: 0.9706 - auc: 0.9966 - val_loss: 1.7053 - val_acc: 0.5085 - val_auc: 0.5491
# Epoch 61/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.0586 - acc: 0.9803 - auc: 0.9991 - val_loss: 2.2754 - val_acc: 0.5593 - val_auc: 0.5160
# Epoch 62/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.0415 - acc: 0.9906 - auc: 0.9993 - val_loss: 6.1511 - val_acc: 0.3898 - val_auc: 0.5276
# Epoch 63/250
# 66/66 [==============================] - 14s 205ms/step - loss: 0.1352 - acc: 0.9525 - auc: 0.9893 - val_loss: 1.8280 - val_acc: 0.5085 - val_auc: 0.4515
# Epoch 64/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.0640 - acc: 0.9811 - auc: 0.9983 - val_loss: 2.1798 - val_acc: 0.5085 - val_auc: 0.4846
# Epoch 65/250
# 66/66 [==============================] - 14s 212ms/step - loss: 0.0700 - acc: 0.9766 - auc: 0.9970 - val_loss: 1.9865 - val_acc: 0.5085 - val_auc: 0.4509
# Epoch 66/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.1312 - acc: 0.9421 - auc: 0.9873 - val_loss: 2.0588 - val_acc: 0.5254 - val_auc: 0.5510
# Epoch 67/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.0856 - acc: 0.9561 - auc: 0.9962 - val_loss: 2.2656 - val_acc: 0.5763 - val_auc: 0.5184
# Epoch 68/250
# 66/66 [==============================] - 14s 205ms/step - loss: 0.0825 - acc: 0.9727 - auc: 0.9961 - val_loss: 2.6585 - val_acc: 0.6102 - val_auc: 0.4631
# Epoch 69/250
# 66/66 [==============================] - 13s 202ms/step - loss: 0.0368 - acc: 0.9910 - auc: 0.9996 - val_loss: 2.5983 - val_acc: 0.5932 - val_auc: 0.5166
#
#
#
#
#
#
#
#
#
# --------------------------------------------------------------------------------
# --------------------	T2W TRAINING LOOP	--------------------
# --------------------------------------------------------------------------------
#
#
#
#
# Epoch 1/250
# 66/66 [==============================] - 16s 220ms/step - loss: 0.7439 - acc: 0.5316 - auc: 0.5138 - val_loss: 0.6833 - val_acc: 0.5932 - val_auc: 0.3810
# Epoch 2/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0.6806 - acc: 0.5986 - auc: 0.6050 - val_loss: 0.7607 - val_acc: 0.5932 - val_auc: 0.5167
# Epoch 3/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.7037 - acc: 0.5538 - auc: 0.5656 - val_loss: 0.6826 - val_acc: 0.5932 - val_auc: 0.6423
# Epoch 4/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0.7217 - acc: 0.5071 - auc: 0.4826 - val_loss: 0.8112 - val_acc: 0.4068 - val_auc: 0.6708
# Epoch 5/250
# 66/66 [==============================] - 14s 211ms/step - loss: 0.6990 - acc: 0.5063 - auc: 0.5383 - val_loss: 0.7656 - val_acc: 0.4068 - val_auc: 0.4536
# Epoch 6/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0.6958 - acc: 0.5309 - auc: 0.5319 - val_loss: 1.1936 - val_acc: 0.4068 - val_auc: 0.6399
# Epoch 7/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.6949 - acc: 0.5114 - auc: 0.5451 - val_loss: 1.2801 - val_acc: 0.4068 - val_auc: 0.6131
# Epoch 8/250
# 66/66 [==============================] - 14s 202ms/step - loss: 0.7110 - acc: 0.5570 - auc: 0.5650 - val_loss: 0.8809 - val_acc: 0.4068 - val_auc: 0.6292
# Epoch 9/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.6865 - acc: 0.5839 - auc: 0.5822 - val_loss: 0.7349 - val_acc: 0.4068 - val_auc: 0.6286
# Epoch 10/250
# 66/66 [==============================] - 14s 211ms/step - loss: 0.6800 - acc: 0.5954 - auc: 0.6160 - val_loss: 0.7525 - val_acc: 0.4237 - val_auc: 0.5982
# Epoch 11/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.
250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.1584 - acc: 0.9465 - auc: 0.9861 - val_loss: 1.3031 - val_acc: 0.5085 - val_auc: 0.4857
# Epoch 49/250
# 66/66 [==============================] - 13s 200ms/step - loss: 0.1061 - acc: 0.9638 - auc: 0.9949 - val_loss: 1.5456 - val_acc: 0.4407 - val_auc: 0.4095
# Epoch 50/250
# 66/66 [==============================] - 14s 215ms/step - loss: 0.1395 - acc: 0.9536 - auc: 0.9902 - val_loss: 1.7210 - val_acc: 0.4407 - val_auc: 0.3780
# Epoch 51/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.1009 - acc: 0.9717 - auc: 0.9950 - val_loss: 2.1166 - val_acc: 0.4576 - val_auc: 0.4744
# Epoch 52/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.0982 - acc: 0.9724 - auc: 0.9962 - val_loss: 1.2750 - val_acc: 0.5254 - val_auc: 0.4869
# Epoch 53/250
# 66/66 [==============================] - 14s 203ms/step - loss: 0.1722 - acc: 0.9281 - auc: 0.9853 - val_loss: 1.5612 - val_acc: 0.4746 - val_auc: 0.4208
# Epoch 54/250
# 66/66 [==============================] - 13s 201ms/step - loss: 0.1301 - acc: 0.9554 - auc: 0.9903 - val_loss: 1.5113 - val_acc: 0.5085 - val_auc: 0.4750

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">6.6  PLOT MODEL TRAINING</h2>
#
# ---
#
# hTBD

# %%
histories
# Out:
# {'flair': <tensorflow.python.keras.callbacks.History at 0x7f03f5785410>,
#  't1w': <tensorflow.python.keras.callbacks.History at 0x7f03fcfb5f10>,
#  't1wce': <tensorflow.python.keras.callbacks.History at 0x7f0443ae3050>,
#  't2w': <tensorflow.python.keras.callbacks.History at 0x7f0441a48290>}

# %% [markdown]
# <br>
#
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #CD0001; background-color: #ffffff;">6.7  MODEL PREDICTIONS</h2>
#
# ---

# %%
model_preds_dfs = {}
for model_style, model in tqdm(models.items(), total=4):
    model_preds_dfs[model_style] = pd.DataFrame()
    model_preds_dfs[model_style]["BraTS21ID"] = flatten_l_o_l([x.tolist() for x in list(dataset_storage[model_style]["test_ds"].map(lambda x,y: y).as_numpy_iterator())])
    model_preds_dfs[model_style][model_style+"_MGMT_value"] = tf.squeeze(model.predict(dataset_storage[model_style]["test_ds"].map(lambda x,y: x)))
    
ss_df = ss_df[["BraTS21ID"]]
for style, style_df in model_preds_dfs.items():
    ss_df = pd.merge(ss_df, style_df, on="BraTS21ID", how="left")
ss_df[["BraTS21ID", "flair_MGMT_value", "t1w_MGMT_value", "t1wce_MGMT_value", "t2w_MGMT_value"]].to_csv("submission.csv", index=False)
display(ss_df)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#     BraTS21ID  flair_MGMT_value  t1w_MGMT_value  t1wce_MGMT_value  \
# 0           1          0.703502        0.108489          0.692113
# 1          13          0.779071        0.174233          0.682556
# 2          15          0.674554        0.675556          0.740450
# 3          27          0.742846        0.544047          0.680860
# 4          37          0.716096        0.493812          0.817064
# ..        ...               ...             ...               ...
# 82        826          0.708073        0.155008          0.703773
# 83        829          0.744198        0.415660          0.772633
# 84        833          0.620252        0.149123          0.601269
# 85        997          0.577571        0.437900          0.641637
# 86       1006          0.686866        0.364766          0.500881
#
#     t2w_MGMT_value
# 0         0.340561
# 1         0.348520
# 2         0.347796
# 3         0.340368
# 4         0.343634
# ..             ...
# 82        0.304098
# 83        0.327834
# 84        0.319204
# 85        0.337601
# 86        0.343156
#
# [87 rows x 5 columns]
